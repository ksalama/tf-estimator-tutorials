# %% [markdown]
# ## UCI Adult Data Set
# ### Dataset URL: https://archive.ics.uci.edu/ml/datasets/adult
# Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset.

# %%
import shutil
import math
from datetime import datetime
import multiprocessing

import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow import data
from tensorflow.python.feature_column import feature_column

print(tf.__version__)
# Out:
# /Users/khalidsalama/anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# 1.4.1

# %%
MODEL_NAME = 'cenus-model-01'

TRAIN_DATA_FILES_PATTERN = 'data/adult.data.csv'
TEST_DATA_FILES_PATTERN = 'data/adult.test.csv'

RESUME_TRAINING = False
PROCESS_FEATURES = True
EXTEND_FEATURE_COLUMNS = True
MULTI_THREADING = True

# %% [markdown]
# ## Define Dataset Metadata

# %%
HEADER = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
               'marital_status', 'occupation', 'relationship', 'race', 'gender',
               'capital_gain', 'capital_loss', 'hours_per_week',
               'native_country', 'income_bracket']

HEADER_DEFAULTS = [[0], [''], [0], [''], [0], [''], [''], [''], [''], [''],
                       [0], [0], [0], [''], ['']]

NUMERIC_FEATURE_NAMES = ['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']

CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY = {
    'gender': ['Female', 'Male'],
    
    'race': ['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'],
    
    'education': ['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college', 
                  'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school', 
                  '5th-6th', '10th', '1st-4th', 'Preschool', '12th'],
    
    'marital_status': ['Married-civ-spouse', 'Divorced', 'Married-spouse-absent', 
                       'Never-married', 'Separated', 'Married-AF-spouse', 'Widowed'],
    
    'relationship': ['Husband', 'Not-in-family', 'Wife', 'Own-child', 'Unmarried', 'Other-relative'],
    
    'workclass': ['Self-emp-not-inc', 'Private', 'State-gov', 'Federal-gov', 'Local-gov', '?', 
                  'Self-emp-inc', 'Without-pay', 'Never-worked']
}

CATEGORICAL_FEATURE_NAMES_WITH_BUCKET_SIZE = {
    'occupation': 50,
    'native_country' : 100
}

CATEGORICAL_FEATURE_NAMES = list(CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.keys()) + list(CATEGORICAL_FEATURE_NAMES_WITH_BUCKET_SIZE.keys())

FEATURE_NAMES = NUMERIC_FEATURE_NAMES + CATEGORICAL_FEATURE_NAMES

TARGET_NAME = 'income_bracket'

TARGET_LABELS = ['<=50K', '>50K']

WEIGHT_COLUMN_NAME = 'fnlwgt'

UNUSED_FEATURE_NAMES = list(set(HEADER) - set(FEATURE_NAMES) - {TARGET_NAME})


print("Header: {}".format(HEADER))
print("Numeric Features: {}".format(NUMERIC_FEATURE_NAMES))
print("Categorical Features: {}".format(CATEGORICAL_FEATURE_NAMES))
print("Target: {} - labels: {}".format(TARGET_NAME, TARGET_LABELS))
print("Unused Features: {}".format(UNUSED_FEATURE_NAMES))
# Out:
# Header: ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'gender', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income_bracket']
# Numeric Features: ['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']
# Categorical Features: ['gender', 'race', 'education', 'marital_status', 'relationship', 'workclass', 'occupation', 'native_country']
# Target: income_bracket - labels: ['<=50K', '>50K']
# Unused Features: []

# %% [markdown]
# ## Load and Analyse Dataset

# %%
TRAIN_DATA_SIZE = 32561
TEST_DATA_SIZE = 16278

train_data = pd.read_csv(TRAIN_DATA_FILES_PATTERN, header=None, names=HEADER )
train_data.head(10)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
# 8   31           Private   45781    Masters             14
# 9   42           Private  159449  Bachelors             13
#
#           marital_status         occupation   relationship   race  gender  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4     Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 5     Married-civ-spouse    Exec-managerial           Wife  White  Female
# 6  Married-spouse-absent      Other-service  Not-in-family  Black  Female
# 7     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 8          Never-married     Prof-specialty  Not-in-family  White  Female
# 9     Married-civ-spouse    Exec-managerial        Husband  White    Male
#
#    capital_gain  capital_loss  hours_per_week native_country income_bracket
# 0          2174             0              40  United-States          <=50K
# 1             0             0              13  United-States          <=50K
# 2             0             0              40  United-States          <=50K
# 3             0             0              40  United-States          <=50K
# 4             0             0              40           Cuba          <=50K
# 5             0             0              40  United-States          <=50K
# 6             0             0              16        Jamaica          <=50K
# 7             0             0              45  United-States           >50K
# 8         14084             0              50  United-States           >50K
# 9          5178             0              40  United-States           >50K

# %%
train_data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### Compute Scaling Statistics for Numeric Columns

# %%
means = train_data[NUMERIC_FEATURE_NAMES].mean(axis=0)
stdvs = train_data[NUMERIC_FEATURE_NAMES].std(axis=0)
maxs = train_data[NUMERIC_FEATURE_NAMES].max(axis=0)
mins = train_data[NUMERIC_FEATURE_NAMES].min(axis=0)
df_stats = pd.DataFrame({"mean":means, "stdv":stdvs, "max":maxs, "min":mins})
df_stats.head(15)
# Out:
#                     max           mean    min           stdv
# age                  90      38.581647     17      13.640433
# fnlwgt          1484705  189778.366512  12285  105549.977697
# education_num        16      10.080679      1       2.572720
# capital_gain      99999    1077.648844      0    7385.292085
# capital_loss       4356      87.303830      0     402.960219
# hours_per_week       99      40.437456      1      12.347429

# %% [markdown]
# ### Save Scaling Statistics

# %%
df_stats.to_csv(path_or_buf="data/adult.stats.csv", header=True, index=True)

# %% [markdown]
# ## Define Data Input Function

# %% [markdown]
# ### a. Parsing and preprocessing logic

# %%
def parse_csv_row(csv_row):
    
    columns = tf.decode_csv(csv_row, record_defaults=HEADER_DEFAULTS)
    features = dict(zip(HEADER, columns))
    
    for column in UNUSED_FEATURE_NAMES:
        features.pop(column)
    
    target = features.pop(TARGET_NAME)

    return features, target

def process_features(features):

    capital_indicator = features['capital_gain'] > features['capital_loss']
    features['capital_indicator'] = tf.cast(capital_indicator, dtype=tf.int32)
    
    return features

# %% [markdown]
# ### b. Data pipeline input function

# %%
def parse_label_column(label_string_tensor):
    table = tf.contrib.lookup.index_table_from_tensor(tf.constant(TARGET_LABELS))
    return table.lookup(label_string_tensor)

def csv_input_fn(files_name_pattern, mode=tf.estimator.ModeKeys.EVAL, 
                 skip_header_lines=0, 
                 num_epochs=None, 
                 batch_size=200):
    
    shuffle = True if mode == tf.estimator.ModeKeys.TRAIN else False
        
    num_threads = multiprocessing.cpu_count() if MULTI_THREADING else 1
     
    print("")
    print("* data input_fn:")
    print("================")
    print("Input file(s): {}".format(files_name_pattern))
    print("Batch size: {}".format(batch_size))
    print("Epoch Count: {}".format(num_epochs))
    print("Mode: {}".format(mode))
    print("Thread Count: {}".format(num_threads))
    print("Shuffle: {}".format(shuffle))
    print("================")
    print("")

    file_names = tf.matching_files(files_name_pattern)
    dataset = data.TextLineDataset(filenames=file_names)
    
    dataset = dataset.skip(skip_header_lines)
    
    if shuffle:
        dataset = dataset.shuffle(buffer_size=2 * batch_size + 1)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda csv_row: parse_csv_row(csv_row), 
                          num_parallel_calls=num_threads)
    
    if PROCESS_FEATURES:
        dataset = dataset.map(lambda features, target: (process_features(features), target), 
                              num_parallel_calls=num_threads)
        
    dataset = dataset.repeat(num_epochs)
    iterator = dataset.make_one_shot_iterator()
    
    features, target = iterator.get_next()
    return features, parse_label_column(target)

# %%
features, target = csv_input_fn(files_name_pattern="")
print("Features in CSV: {}".format(list(features.keys())))
print("Target in CSV: {}".format(target))
# Out:
# * data input_fn:
# ================
# Input file(s):
# Batch size: 200
# Epoch Count: None
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# Features in CSV: ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'gender', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'capital_indicator']
# Target in CSV: Tensor("hash_table_Lookup:0", shape=(?,), dtype=int64)

# %% [markdown]
# ## Define Feature Columns
# ### a. Load scaling params

# %%
df_stats = pd.read_csv("data/adult.stats.csv", header=0, index_col=0)
df_stats['feature_name'] = NUMERIC_FEATURE_NAMES
df_stats.head(10)
# Out:
#                     max           mean    min           stdv    feature_name
# age                  90      38.581647     17      13.640433             age
# fnlwgt          1484705  189778.366512  12285  105549.977697          fnlwgt
# education_num        16      10.080679      1       2.572720   education_num
# capital_gain      99999    1077.648844      0    7385.292085    capital_gain
# capital_loss       4356      87.303830      0     402.960219    capital_loss
# hours_per_week       99      40.437456      1      12.347429  hours_per_week

# %% [markdown]
# ### b. Create feature columns

# %%
def extend_feature_columns(feature_columns, hparams):
    
    age_buckets = tf.feature_column.bucketized_column(
      feature_columns['age'], boundaries=[18, 25, 30, 35, 40, 45, 50, 55, 60, 65])
    
    education_X_occupation = tf.feature_column.crossed_column(
     ['education', 'occupation'], hash_bucket_size=int(1e4))
    
    age_buckets_X_race = tf.feature_column.crossed_column(
     [age_buckets, feature_columns['race']], hash_bucket_size=int(1e4))
    
    native_country_X_occupation = tf.feature_column.crossed_column(
          ['native_country', 'occupation'], hash_bucket_size=int(1e4))
    
    native_country_embedded = tf.feature_column.embedding_column(
          feature_columns['native_country'], dimension=hparams.embedding_size)
    
    occupation_embedded = tf.feature_column.embedding_column(
          feature_columns['occupation'], dimension=hparams.embedding_size)
    
    education_X_occupation_embedded = tf.feature_column.embedding_column(
          education_X_occupation, dimension=hparams.embedding_size)
    
    native_country_X_occupation_embedded = tf.feature_column.embedding_column(
          native_country_X_occupation, dimension=hparams.embedding_size)
    
    
    feature_columns['age_buckets'] = age_buckets
    feature_columns['education_X_occupation'] = education_X_occupation
    feature_columns['age_buckets_X_race'] = age_buckets_X_race
    feature_columns['native_country_X_occupation'] = native_country_X_occupation
    feature_columns['native_country_embedded'] = native_country_embedded
    feature_columns['occupation_embedded'] = occupation_embedded
    feature_columns['education_X_occupation_embedded'] = education_X_occupation_embedded
    feature_columns['native_country_X_occupation_embedded'] = native_country_X_occupation_embedded
    
    return feature_columns

def standard_scaler(x, mean, stdv):
    return (x-mean)/(stdv)

def maxmin_scaler(x, max_value, min_value):
    return (x-min_value)/(max_value-min_value)  

def get_feature_columns(hparams):
    
    
    numeric_columns = {}
    
    for feature_name in NUMERIC_FEATURE_NAMES:

        feature_mean = df_stats[df_stats.feature_name == feature_name]['mean'].values[0]
        feature_stdv = df_stats[df_stats.feature_name == feature_name]['stdv'].values[0]
        normalizer_fn = lambda x: standard_scaler(x, feature_mean, feature_stdv)
        
        numeric_columns[feature_name] = tf.feature_column.numeric_column(feature_name, 
                                                                         normalizer_fn=normalizer_fn
                                                                        )
    CONSTRUCTED_NUMERIC_FEATURES_NAMES = []
    
    if PROCESS_FEATURES:
        for feature_name in CONSTRUCTED_NUMERIC_FEATURES_NAMES:
            numeric_columns[feature_name] = tf.feature_column.numeric_column(feature_name)
    
    categorical_column_with_vocabulary = \
        {item[0]: tf.feature_column.categorical_column_with_vocabulary_list(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.items()}
        
    CONSTRUCTED_INDICATOR_FEATURES_NAMES = ['capital_indicator']
    
    categorical_column_with_identity = {}
    
    for feature_name in CONSTRUCTED_INDICATOR_FEATURES_NAMES: 
        categorical_column_with_identity[feature_name] = tf.feature_column.categorical_column_with_identity(feature_name, 
                                                                                                              num_buckets=2,
                                                                                                              default_value=0)
    categorical_column_with_hash_bucket = \
        {item[0]: tf.feature_column.categorical_column_with_hash_bucket(item[0], item[1], dtype=tf.string)
         for item in CATEGORICAL_FEATURE_NAMES_WITH_BUCKET_SIZE.items()}
        
    feature_columns = {}

    if numeric_columns is not None:
        feature_columns.update(numeric_columns)

    if categorical_column_with_vocabulary is not None:
        feature_columns.update(categorical_column_with_vocabulary)
        
    if categorical_column_with_identity is not None:
        feature_columns.update(categorical_column_with_identity)
        
    if categorical_column_with_hash_bucket is not None:
        feature_columns.update(categorical_column_with_hash_bucket)
    
    if EXTEND_FEATURE_COLUMNS:
        feature_columns = extend_feature_columns(feature_columns, hparams)
        
    return feature_columns

feature_columns = get_feature_columns(tf.contrib.training.HParams(num_buckets=5,embedding_size=3))
print("Feature Columns: {}".format(feature_columns))
# Out:
# Feature Columns: {'age': _NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f196510>), 'fnlwgt': _NumericColumn(key='fnlwgt', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f196378>), 'education_num': _NumericColumn(key='education_num', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f196598>), 'capital_gain': _NumericColumn(key='capital_gain', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f196620>), 'capital_loss': _NumericColumn(key='capital_loss', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f1966a8>), 'hours_per_week': _NumericColumn(key='hours_per_week', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f196730>), 'gender': _VocabularyListCategoricalColumn(key='gender', vocabulary_list=('Female', 'Male'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'race': _VocabularyListCategoricalColumn(key='race', vocabulary_list=('Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'education': _VocabularyListCategoricalColumn(key='education', vocabulary_list=('Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college', 'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school', '5th-6th', '10th', '1st-4th', 'Preschool', '12th'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'marital_status': _VocabularyListCategoricalColumn(key='marital_status', vocabulary_list=('Married-civ-spouse', 'Divorced', 'Married-spouse-absent', 'Never-married', 'Separated', 'Married-AF-spouse', 'Widowed'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'relationship': _VocabularyListCategoricalColumn(key='relationship', vocabulary_list=('Husband', 'Not-in-family', 'Wife', 'Own-child', 'Unmarried', 'Other-relative'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'workclass': _VocabularyListCategoricalColumn(key='workclass', vocabulary_list=('Self-emp-not-inc', 'Private', 'State-gov', 'Federal-gov', 'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'capital_indicator': _IdentityCategoricalColumn(key='capital_indicator', num_buckets=2, default_value=0), 'occupation': _HashedCategoricalColumn(key='occupation', hash_bucket_size=50, dtype=tf.string), 'native_country': _HashedCategoricalColumn(key='native_country', hash_bucket_size=100, dtype=tf.string), 'age_buckets': _BucketizedColumn(source_column=_NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f196510>), boundaries=(18, 25, 30, 35, 40, 45, 50, 55, 60, 65)), 'education_X_occupation': _CrossedColumn(keys=('education', 'occupation'), hash_bucket_size=10000, hash_key=None), 'age_buckets_X_race': _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f196510>), boundaries=(18, 25, 30, 35, 40, 45, 50, 55, 60, 65)), _VocabularyListCategoricalColumn(key='race', vocabulary_list=('Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=10000, hash_key=None), 'native_country_X_occupation': _CrossedColumn(keys=('native_country', 'occupation'), hash_bucket_size=10000, hash_key=None), 'native_country_embedded': _EmbeddingColumn(categorical_column=_HashedCategoricalColumn(key='native_country', hash_bucket_size=100, dtype=tf.string), dimension=3, combiner='mean', initiali ...

# %% [markdown]
# ## Define a DNN  Estimator Creation Function

# %% [markdown]
# ### a. Get wide and deep feature columns

# %%
def get_wide_deep_columns():
    
    feature_columns = list(get_feature_columns(hparams).values())
    
    dense_columns = list(
        filter(lambda column: isinstance(column, feature_column._NumericColumn) |
                              isinstance(column, feature_column._EmbeddingColumn),
               feature_columns
        )
    )

    categorical_columns = list(
        filter(lambda column: isinstance(column, feature_column._VocabularyListCategoricalColumn) |
                              isinstance(column, feature_column._IdentityCategoricalColumn) |
                              isinstance(column, feature_column._BucketizedColumn),
                   feature_columns)
    )
    
    sparse_columns = list(
        filter(lambda column: isinstance(column,feature_column._HashedCategoricalColumn) |
                              isinstance(column, feature_column._CrossedColumn),
               feature_columns)
    )

    indicator_columns = list(
            map(lambda column: tf.feature_column.indicator_column(column),
                categorical_columns)
    )
    
    deep_feature_columns = dense_columns + indicator_columns
    wide_feature_columns = categorical_columns + sparse_columns
    
    return wide_feature_columns, deep_feature_columns

# %% [markdown]
# ### b. Define the estimator

# %%
def create_DNNComb_estimator(run_config, hparams, print_desc=False):
    
    wide_feature_columns, deep_feature_columns = get_wide_deep_columns()
    
    estimator = tf.estimator.DNNLinearCombinedClassifier(
        
        n_classes=len(TARGET_LABELS),
        
        dnn_feature_columns = deep_feature_columns,
        linear_feature_columns = wide_feature_columns,
        
        weight_column=WEIGHT_COLUMN_NAME,
        
        dnn_hidden_units= hparams.hidden_units,
        
        dnn_optimizer= tf.train.AdamOptimizer(),
        
        dnn_activation_fn= tf.nn.relu,
        
        config= run_config
    )
    
    
    if print_desc:
        print("")
        print("*Estimator Type:")
        print("================")
        print(type(estimator))
        print("")
        print("*deep columns:")
        print("==============")
        print(deep_feature_columns)
        print("")
        print("wide columns:")
        print("=============")
        print(wide_feature_columns)
        print("")
    
    return estimator

# %% [markdown]
# ## 6. Run Experiment

# %% [markdown]
# ### a. Set HParam and RunConfig

# %%
TRAIN_SIZE = TRAIN_DATA_SIZE
NUM_EPOCHS = 1000
BATCH_SIZE = 500
EVAL_AFTER_SEC = 60
TOTAL_STEPS = (TRAIN_SIZE/BATCH_SIZE)*NUM_EPOCHS

hparams  = tf.contrib.training.HParams(
    num_epochs = NUM_EPOCHS,
    batch_size = BATCH_SIZE,
    embedding_size = 4,
    hidden_units= [64, 32, 16],
    max_steps = TOTAL_STEPS
)

model_dir = 'trained_models/{}'.format(MODEL_NAME)

run_config = tf.estimator.RunConfig(
    log_step_count_steps=5000,
    tf_random_seed=19830610,
    model_dir=model_dir
)

print(hparams)
print("Model Directory:", run_config.model_dir)
print("")
print("Dataset Size:", TRAIN_SIZE)
print("Batch Size:", BATCH_SIZE)
print("Steps per Epoch:",TRAIN_SIZE/BATCH_SIZE)
print("Total Steps:", TOTAL_STEPS)
print("That is 1 evaluation step after each",EVAL_AFTER_SEC," training seconds")
# Out:
# [('batch_size', 500), ('embedding_size', 4), ('hidden_units', [64, 32, 16]), ('max_steps', 65122.0), ('num_epochs', 1000)]
# Model Directory: trained_models/cenus-model-01
#
# Dataset Size: 32561
# Batch Size: 500
# Steps per Epoch: 65.122
# Total Steps: 65122.0
# That is 1 evaluation step after each 60  training seconds

# %% [markdown]
# ### b. Define TrainSpec and EvaluSpec

# %%
train_spec = tf.estimator.TrainSpec(
    input_fn = lambda: csv_input_fn(
        TRAIN_DATA_FILES_PATTERN,
        mode = tf.estimator.ModeKeys.TRAIN,
        num_epochs=hparams.num_epochs,
        batch_size=hparams.batch_size
    ),
    max_steps=hparams.max_steps,
    hooks=None
)

eval_spec = tf.estimator.EvalSpec(
    input_fn = lambda: csv_input_fn(
        TRAIN_DATA_FILES_PATTERN,
        mode=tf.estimator.ModeKeys.EVAL,
        num_epochs=1,
        batch_size=hparams.batch_size,
            
    ),
    throttle_secs = EVAL_AFTER_SEC,
    steps=None
)

# %% [markdown]
# ### c. Run Experiment via train_and_evaluate

# %%
if not RESUME_TRAINING:
    print("Removing previous artifacts...")
    shutil.rmtree(model_dir, ignore_errors=True)
else:
    print("Resuming training...") 

    
tf.logging.set_verbosity(tf.logging.INFO)

time_start = datetime.utcnow() 
print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
print(".......................................") 

estimator = create_DNNComb_estimator(run_config, hparams, True)

tf.estimator.train_and_evaluate(
    estimator=estimator,
    train_spec=train_spec, 
    eval_spec=eval_spec
)

time_end = datetime.utcnow() 
print(".......................................")
print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
print("")
time_elapsed = time_end - time_start
print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
# Out:
# Removing previous artifacts...
# Experiment started at 23:22:17
# .......................................
# INFO:tensorflow:Using config: {'_model_dir': 'trained_models/cenus-model-01', '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 5000, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11f1dd748>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# *Estimator Type:
# ================
# <class 'tensorflow.python.estimator.canned.dnn_linear_combined.DNNLinearCombinedClassifier'>
#
# *deep columns:
# ==============
# [_NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f1c28c8>), _NumericColumn(key='fnlwgt', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f1c27b8>), _NumericColumn(key='education_num', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f1c2510>), _NumericColumn(key='capital_gain', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f1c2488>), _NumericColumn(key='capital_loss', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f1c2048>), _NumericColumn(key='hours_per_week', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f1c2ae8>), _EmbeddingColumn(categorical_column=_HashedCategoricalColumn(key='native_country', hash_bucket_size=100, dtype=tf.string), dimension=4, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x11f1c9470>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True), _EmbeddingColumn(categorical_column=_HashedCategoricalColumn(key='occupation', hash_bucket_size=50, dtype=tf.string), dimension=4, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x11f1c9828>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True), _EmbeddingColumn(categorical_column=_CrossedColumn(keys=('education', 'occupation'), hash_bucket_size=10000, hash_key=None), dimension=4, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x11f1c99e8>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True), _EmbeddingColumn(categorical_column=_CrossedColumn(keys=('native_country', 'occupation'), hash_bucket_size=10000, hash_key=None), dimension=4, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x11f1c9b00>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='gender', vocabulary_list=('Female', 'Male'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='race', vocabulary_list=('Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='education', vocabulary_list=('Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college', 'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school', '5th-6th', '10th', '1st-4th', 'Preschool', '12th'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='marital_status', vocabulary_list=('Married-civ-spouse', 'Divorced', 'Married-spouse-absent', 'Never-married', 'Separated', 'Married-AF-spouse', 'Widowed'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='relationship', vocabulary_list=('Husband', 'Not-in-family', 'Wife', 'Own-child', 'Unmarried', 'Other-relative'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='workclass', vocabulary_list=('Self-emp-not-inc', 'Private', 'State-gov', 'Federal-gov', 'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_IdentityCategoricalColumn(key='capital_indicator', num_buckets=2, default_value=0)), _IndicatorColumn(categorical_column=_BucketizedColumn(source_c ...
#
# wide columns:
# =============
# [_VocabularyListCategoricalColumn(key='gender', vocabulary_list=('Female', 'Male'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='race', vocabulary_list=('Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='education', vocabulary_list=('Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college', 'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school', '5th-6th', '10th', '1st-4th', 'Preschool', '12th'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='marital_status', vocabulary_list=('Married-civ-spouse', 'Divorced', 'Married-spouse-absent', 'Never-married', 'Separated', 'Married-AF-spouse', 'Widowed'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='relationship', vocabulary_list=('Husband', 'Not-in-family', 'Wife', 'Own-child', 'Unmarried', 'Other-relative'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='workclass', vocabulary_list=('Self-emp-not-inc', 'Private', 'State-gov', 'Federal-gov', 'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _IdentityCategoricalColumn(key='capital_indicator', num_buckets=2, default_value=0), _BucketizedColumn(source_column=_NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f1c28c8>), boundaries=(18, 25, 30, 35, 40, 45, 50, 55, 60, 65)), _HashedCategoricalColumn(key='occupation', hash_bucket_size=50, dtype=tf.string), _HashedCategoricalColumn(key='native_country', hash_bucket_size=100, dtype=tf.string), _CrossedColumn(keys=('education', 'occupation'), hash_bucket_size=10000, hash_key=None), _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x11f1c28c8>), boundaries=(18, 25, 30, 35, 40, 45, 50, 55, 60, 65)), _VocabularyListCategoricalColumn(key='race', vocabulary_list=('Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=10000, hash_key=None), _CrossedColumn(keys=('native_country', 'occupation'), hash_bucket_size=10000, hash_key=None)]
#
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 60 secs (eval_spec.throttle_secs) or training is finished.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 6.5364e+09, step = 1
# INFO:tensorflow:loss = 1.68334e+09, step = 101 (1.179 sec)
# INFO:tensorflow:loss = 1.83366e+08, step = 201 (0.625 sec)
# INFO:tensorflow:loss = 1.04785e+08, step = 301 (0.639 sec)
# INFO:tensorflow:loss = 5.595e+08, step = 401 (0.616 sec)
# INFO:tensorflow:loss = 1.12901e+08, step = 501 (0.616 sec)
# INFO:tensorflow:loss = 1.31533e+08, step = 601 (0.613 sec)
# INFO:tensorflow:loss = 2.23135e+08, step = 701 (0.617 sec)
# INFO:tensorflow:loss = 6.42206e+07, step = 801 (0.617 sec)
# INFO:tensorflow:loss = 1.84873e+08, step = 901 (0.620 sec)
# INFO:tensorflow:loss = 1.06171e+08, step = 1001 (0.613 sec)
# INFO:tensorflow:loss = 2.0627e+08, step = 1101 (0.617 sec)
# INFO:tensorflow:loss = 5.64006e+07, step = 1201 (0.633 sec)
# INFO:tensorflow:loss = 9.15162e+07, step = 1301 (0.632 sec)
# INFO:tensorflow:loss = 4.70419e+07, step = 1401 (0.631 sec)
# INFO:tensorflow:loss = 5.90472e+07, step = 1501 (0.632 sec)
# INFO:tensorflow:loss = 1.31396e+08, step = 1601 (0.629 sec)
# INFO:tensorflow:loss = 2.99965e+08, step = 1701 (0.635 sec)
# INFO:tensorflow:loss = 1.0285e+08, step = 1801 (0.633 sec)
# INFO:tensorflow:loss = 1.35575e+08, step = 1901 (0.636 sec)
# INFO:tensorflow:loss = 1.30158e+08, step = 2001 (0.627 sec)
# INFO:tensorflow:loss = 7.67706e+08, step = 2101 (0.634 sec)
# INFO:tensorflow:loss = 1.00738e+08, step = 2201 (0.631 sec)
# INFO:tensorflow:loss = 2.06645e+08, step = 2301 (0.636 sec)
# INFO:tensorflow:loss = 9.05023e+07, step = 2401 (0.748 sec)
# INFO:tensorflow:loss = 3.47404e+07, step = 2501 (0.645 sec)
# INFO:tensorflow:loss = 3.73963e+07, step = 2601 (0.637 sec)
# INFO:tensorflow:loss = 3.7643e+07, step = 2701 (0.640 sec)
# INFO:tensorflow:loss = 5.30289e+07, step = 2801 (0.636 sec)
# INFO:tensorflow:loss = 4.59609e+07, step = 2901 (0.648 sec)
# INFO:tensorflow:loss = 3.9879e+07, step = 3001 (0.649 sec)
# INFO:tensorflow:loss = 3.843e+07, step = 3101 (0.640 sec)
# INFO:tensorflow:loss = 1.28718e+08, step = 3201 (0.634 sec)
# INFO:tensorflow:loss = 1.73567e+08, step = 3301 (0.628 sec)
# INFO:tensorflow:loss = 3.85103e+07, step = 3401 (0.629 sec)
# INFO:tensorflow:loss = 1.06414e+08, step = 3501 (0.669 sec)
# INFO:tensorflow:loss = 3.04857e+07, step = 3601 (0.650 sec)
# INFO:tensorflow:loss = 6.155e+07, step = 3701 (0.650 sec)
# INFO:tensorflow:loss = 1.48644e+08, step = 3801 (0.628 sec)
# INFO:tensorflow:loss = 3.85081e+08, step = 3901 (0.628 sec)
# INFO:tensorflow:loss = 6.02282e+07, step = 4001 (0.635 sec)
# INFO:tensorflow:loss = 5.74772e+07, step = 4101 (0.627 sec)
# INFO:tensorflow:loss = 3.63694e+07, step = 4201 (0.628 sec)
# INFO:tensorflow:loss = 4.07131e+07, step = 4301 (0.631 sec)
# INFO:tensorflow:loss = 7.80344e+07, step = 4401 (0.630 sec)
# INFO:tensorflow:loss = 5.81229e+07, step = 4501 (0.625 sec)
# INFO:tensorflow:loss = 3.01397e+07, step = 4601 (0.646 sec)
# INFO:tensorflow:loss = 3.26485e+07, step = 4701 (0.630 sec)
# INFO:tensorflow:loss = 5.01634e+07, step = 4801 (0.656 sec)
# INFO:tensorflow:loss = 2.90123e+07, step = 4901 (0.668 sec)
# INFO:tensorflow:global_step/sec: 154.504
# INFO:tensorflow:loss = 4.67008e+07, step = 5001 (0.669 sec)
# INFO:tensorflow:loss = 2.93827e+07, step = 5101 (0.976 sec)
# INFO:tensorflow:loss = 2.26074e+08, step = 5201 (0.658 sec)
# INFO:tensorflow:loss = 3.62076e+07, step = 5301 (0.693 sec)
# INFO:tensorflow:loss = 2.78406e+07, step = 5401 (0.660 sec)
# INFO:tensorflow:loss = 8.85836e+07, step = 5501 (0.625 sec)
# INFO:tensorflow:loss = 3.3038e+07, step = 5601 (0.637 sec)
# INFO:tensorflow:loss = 3.72374e+07, step = 5701 (0.624 sec)
# INFO:tensorflow:loss = 3.76681e+07, step = 5801 (0.631 sec)
# INFO:tensorflow:loss = 2.6935e+07, step = 5901 (0.626 sec)
# INFO:tensorflow:loss = 3.90811e+07, step = 6001 (0.621 sec)
# INFO:tensorflow:loss = 6.98997e+07, step = 6101 (0.631 sec)
# INFO:tensorflow:loss = 2.60576e+07, step = 6201 (0.628 sec)
# INFO:tensorflow:loss = 3.80942e+07, step = 6301 (0.629 sec)
# INFO:tensorflow:loss = 3.7826e+07, step = 6401 (0.624 sec)
# INFO:tensorflow:loss = 4.56343e+07, step = 6501 (0.643 sec)
# INFO:tensorflow:loss = 3.34054e+07, step = 6601 (0.628 sec)
# INFO:tensorflow:loss = 3.84805e+07, step = 6701 (0.628 sec)
# INFO:tensorflow:loss = 6.21146e+07, step = 6801 (0.629 sec)
# INFO:tensorflow:loss = 3.266e+07, step = 6901 (0.633 sec)
# INFO:tensorflow:loss = 2.83894e+07, step = 7001 (0.660 sec)
# INFO:tensorflow:loss = 3.15157e+07, step = 7101 (0.634 sec)
# INFO:tensorflow:Saving checkpoints for 7195 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.23424e+08.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:23:33
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-7195
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:23:36
# INFO:tensorflow:Saving dict for global step 7195: accuracy = 0.799373, accuracy_baseline = 0.761441, auc = 0.769033, auc_precision_recall = 0.64183, average_loss = 1.00547, global_step = 7195, label/mean = 0.238559, loss = 9.41394e+07, prediction/mean = 0.0570299
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-7195
# INFO:tensorflow:Saving checkpoints for 7196 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 1.04602e+08, step = 7196
# INFO:tensorflow:loss = 3.4999e+07, step = 7296 (1.272 sec)
# INFO:tensorflow:loss = 4.3035e+07, step = 7396 (0.649 sec)
# INFO:tensorflow:loss = 2.92232e+07, step = 7496 (0.630 sec)
# INFO:tensorflow:loss = 2.81609e+07, step = 7596 (0.622 sec)
# INFO:tensorflow:loss = 3.2368e+07, step = 7696 (0.622 sec)
# INFO:tensorflow:loss = 2.9826e+07, step = 7796 (0.617 sec)
# INFO:tensorflow:loss = 3.19307e+07, step = 7896 (0.626 sec)
# INFO:tensorflow:loss = 3.15585e+07, step = 7996 (0.625 sec)
# INFO:tensorflow:loss = 2.89896e+07, step = 8096 (0.620 sec)
# INFO:tensorflow:loss = 2.83669e+07, step = 8196 (0.620 sec)
# INFO:tensorflow:loss = 3.47275e+07, step = 8296 (0.623 sec)
# INFO:tensorflow:loss = 3.19979e+07, step = 8396 (0.620 sec)
# INFO:tensorflow:loss = 5.54854e+07, step = 8496 (0.623 sec)
# INFO:tensorflow:loss = 2.65897e+07, step = 8596 (0.617 sec)
# INFO:tensorflow:loss = 2.48192e+07, step = 8696 (0.625 sec)
# INFO:tensorflow:loss = 2.62292e+07, step = 8796 (0.617 sec)
# INFO:tensorflow:loss = 3.73611e+07, step = 8896 (0.624 sec)
# INFO:tensorflow:loss = 3.45878e+07, step = 8996 (0.625 sec)
# INFO:tensorflow:loss = 2.85293e+07, step = 9096 (0.625 sec)
# INFO:tensorflow:loss = 3.22186e+07, step = 9196 (0.618 sec)
# INFO:tensorflow:loss = 5.93341e+07, step = 9296 (0.623 sec)
# INFO:tensorflow:loss = 3.0344e+07, step = 9396 (0.620 sec)
# INFO:tensorflow:loss = 1.13449e+08, step = 9496 (0.633 sec)
# INFO:tensorflow:loss = 5.48857e+07, step = 9596 (0.620 sec)
# INFO:tensorflow:loss = 3.26715e+07, step = 9696 (0.623 sec)
# INFO:tensorflow:loss = 3.02618e+07, step = 9796 (0.629 sec)
# INFO:tensorflow:loss = 2.90398e+07, step = 9896 (0.616 sec)
# INFO:tensorflow:loss = 3.32279e+07, step = 9996 (0.625 sec)
# INFO:tensorflow:loss = 4.6672e+07, step = 10096 (0.616 sec)
# INFO:tensorflow:loss = 3.37102e+07, step = 10196 (0.620 sec)
# INFO:tensorflow:loss = 2.80857e+07, step = 10296 (0.617 sec)
# INFO:tensorflow:loss = 3.12144e+07, step = 10396 (0.627 sec)
# INFO:tensorflow:loss = 5.14778e+07, step = 10496 (0.626 sec)
# INFO:tensorflow:loss = 3.00617e+07, step = 10596 (0.625 sec)
# INFO:tensorflow:loss = 3.19576e+07, step = 10696 (0.615 sec)
# INFO:tensorflow:loss = 2.77259e+07, step = 10796 (0.630 sec)
# INFO:tensorflow:loss = 7.71979e+08, step = 10896 (0.622 sec)
# INFO:tensorflow:loss = 2.79466e+07, step = 10996 (0.624 sec)
# INFO:tensorflow:loss = 2.86639e+07, step = 11096 (0.619 sec)
# INFO:tensorflow:loss = 2.92995e+07, step = 11196 (0.618 sec)
# INFO:tensorflow:loss = 3.50311e+07, step = 11296 (0.641 sec)
# INFO:tensorflow:loss = 3.93921e+07, step = 11396 (0.619 sec)
# INFO:tensorflow:loss = 2.9841e+07, step = 11496 (0.658 sec)
# INFO:tensorflow:loss = 3.84745e+07, step = 11596 (0.627 sec)
# INFO:tensorflow:loss = 2.78128e+07, step = 11696 (0.621 sec)
# INFO:tensorflow:loss = 3.00118e+07, step = 11796 (0.624 sec)
# INFO:tensorflow:loss = 2.64916e+07, step = 11896 (0.617 sec)
# INFO:tensorflow:loss = 3.18369e+07, step = 11996 (0.630 sec)
# INFO:tensorflow:loss = 2.80614e+07, step = 12096 (0.618 sec)
# INFO:tensorflow:global_step/sec: 157.031
# INFO:tensorflow:loss = 2.5901e+07, step = 12196 (0.619 sec)
# INFO:tensorflow:loss = 2.57176e+07, step = 12296 (0.616 sec)
# INFO:tensorflow:loss = 2.73206e+07, step = 12396 (0.631 sec)
# INFO:tensorflow:loss = 3.02439e+07, step = 12496 (0.628 sec)
# INFO:tensorflow:loss = 2.61246e+07, step = 12596 (0.627 sec)
# INFO:tensorflow:loss = 3.55542e+07, step = 12696 (0.616 sec)
# INFO:tensorflow:loss = 3.5754e+07, step = 12796 (0.618 sec)
# INFO:tensorflow:loss = 3.29661e+07, step = 12896 (0.617 sec)
# INFO:tensorflow:loss = 3.8542e+07, step = 12996 (0.627 sec)
# INFO:tensorflow:loss = 2.43692e+07, step = 13096 (0.619 sec)
# INFO:tensorflow:loss = 2.99774e+07, step = 13196 (0.620 sec)
# INFO:tensorflow:loss = 3.36655e+07, step = 13296 (0.624 sec)
# INFO:tensorflow:loss = 2.64853e+07, step = 13396 (0.619 sec)
# INFO:tensorflow:loss = 2.88144e+07, step = 13496 (0.624 sec)
# INFO:tensorflow:loss = 3.25697e+07, step = 13596 (0.619 sec)
# INFO:tensorflow:loss = 2.93682e+07, step = 13696 (0.638 sec)
# INFO:tensorflow:loss = 2.96103e+07, step = 13796 (0.631 sec)
# INFO:tensorflow:loss = 3.05737e+07, step = 13896 (0.626 sec)
# INFO:tensorflow:loss = 3.21549e+07, step = 13996 (0.618 sec)
# INFO:tensorflow:loss = 2.59667e+07, step = 14096 (0.622 sec)
# INFO:tensorflow:loss = 2.73714e+07, step = 14196 (0.628 sec)
# INFO:tensorflow:loss = 3.01326e+07, step = 14296 (0.626 sec)
# INFO:tensorflow:loss = 2.66937e+07, step = 14396 (0.627 sec)
# INFO:tensorflow:loss = 3.05092e+07, step = 14496 (0.621 sec)
# INFO:tensorflow:Saving checkpoints for 14514 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.24002e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:24:51
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-14514
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:24:54
# INFO:tensorflow:Saving dict for global step 14514: accuracy = 0.856448, accuracy_baseline = 0.761441, auc = 0.917583, auc_precision_recall = 0.786894, average_loss = 0.304702, global_step = 14514, label/mean = 0.238559, loss = 2.85283e+07, prediction/mean = 0.2176
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-14514
# INFO:tensorflow:Saving checkpoints for 14515 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.11872e+07, step = 14515
# INFO:tensorflow:loss = 3.16952e+07, step = 14615 (1.525 sec)
# INFO:tensorflow:loss = 3.14169e+07, step = 14715 (0.655 sec)
# INFO:tensorflow:loss = 2.84016e+07, step = 14815 (0.633 sec)
# INFO:tensorflow:loss = 3.04948e+07, step = 14915 (0.619 sec)
# INFO:tensorflow:loss = 2.55313e+07, step = 15015 (0.626 sec)
# INFO:tensorflow:loss = 2.98655e+07, step = 15115 (0.626 sec)
# INFO:tensorflow:loss = 2.95097e+07, step = 15215 (0.700 sec)
# INFO:tensorflow:loss = 2.74362e+07, step = 15315 (0.789 sec)
# INFO:tensorflow:loss = 2.83233e+07, step = 15415 (0.748 sec)
# INFO:tensorflow:loss = 2.84202e+07, step = 15515 (0.632 sec)
# INFO:tensorflow:loss = 2.86868e+07, step = 15615 (0.658 sec)
# INFO:tensorflow:loss = 2.83995e+07, step = 15715 (0.776 sec)
# INFO:tensorflow:loss = 3.07228e+07, step = 15815 (0.823 sec)
# INFO:tensorflow:loss = 2.60661e+07, step = 15915 (0.905 sec)
# INFO:tensorflow:loss = 2.61053e+07, step = 16015 (0.638 sec)
# INFO:tensorflow:loss = 2.6117e+07, step = 16115 (0.645 sec)
# INFO:tensorflow:loss = 2.94307e+07, step = 16215 (0.892 sec)
# INFO:tensorflow:loss = 2.94306e+07, step = 16315 (0.881 sec)
# INFO:tensorflow:loss = 2.97446e+07, step = 16415 (0.772 sec)
# INFO:tensorflow:loss = 3.24163e+07, step = 16515 (0.860 sec)
# INFO:tensorflow:loss = 2.71181e+07, step = 16615 (0.929 sec)
# INFO:tensorflow:loss = 2.67589e+07, step = 16715 (0.905 sec)
# INFO:tensorflow:loss = 3.48549e+07, step = 16815 (0.776 sec)
# INFO:tensorflow:loss = 3.72275e+07, step = 16915 (0.801 sec)
# INFO:tensorflow:loss = 2.78845e+07, step = 17015 (0.790 sec)
# INFO:tensorflow:loss = 2.83807e+07, step = 17115 (0.785 sec)
# INFO:tensorflow:loss = 2.78956e+07, step = 17215 (0.783 sec)
# INFO:tensorflow:loss = 3.8676e+07, step = 17315 (0.776 sec)
# INFO:tensorflow:loss = 3.13828e+07, step = 17415 (0.794 sec)
# INFO:tensorflow:loss = 3.11073e+07, step = 17515 (0.787 sec)
# INFO:tensorflow:loss = 2.90419e+07, step = 17615 (0.761 sec)
# INFO:tensorflow:loss = 3.14286e+07, step = 17715 (0.652 sec)
# INFO:tensorflow:loss = 3.58077e+07, step = 17815 (0.639 sec)
# INFO:tensorflow:loss = 2.99225e+07, step = 17915 (0.626 sec)
# INFO:tensorflow:loss = 3.30853e+07, step = 18015 (0.623 sec)
# INFO:tensorflow:loss = 4.1245e+07, step = 18115 (0.620 sec)
# INFO:tensorflow:loss = 2.74105e+07, step = 18215 (0.625 sec)
# INFO:tensorflow:loss = 2.78445e+07, step = 18315 (0.623 sec)
# INFO:tensorflow:loss = 2.95501e+07, step = 18415 (0.678 sec)
# INFO:tensorflow:loss = 3.39323e+07, step = 18515 (0.827 sec)
# INFO:tensorflow:loss = 2.6395e+07, step = 18615 (0.693 sec)
# INFO:tensorflow:loss = 3.10619e+07, step = 18715 (0.736 sec)
# INFO:tensorflow:loss = 2.96738e+07, step = 18815 (0.923 sec)
# INFO:tensorflow:loss = 3.04634e+07, step = 18915 (1.183 sec)
# INFO:tensorflow:loss = 3.05389e+07, step = 19015 (0.866 sec)
# INFO:tensorflow:loss = 3.00439e+07, step = 19115 (0.832 sec)
# INFO:tensorflow:loss = 2.60741e+07, step = 19215 (0.963 sec)
# INFO:tensorflow:loss = 3.06507e+07, step = 19315 (0.857 sec)
# INFO:tensorflow:loss = 2.52346e+07, step = 19415 (0.815 sec)
# INFO:tensorflow:global_step/sec: 128.2
# INFO:tensorflow:loss = 2.54464e+07, step = 19515 (0.933 sec)
# INFO:tensorflow:loss = 3.20423e+07, step = 19615 (0.789 sec)
# INFO:tensorflow:loss = 2.57935e+07, step = 19715 (0.757 sec)
# INFO:tensorflow:loss = 3.54924e+07, step = 19815 (0.744 sec)
# INFO:tensorflow:loss = 3.33018e+07, step = 19915 (0.817 sec)
# INFO:tensorflow:loss = 3.43076e+07, step = 20015 (0.814 sec)
# INFO:tensorflow:loss = 3.26298e+07, step = 20115 (0.849 sec)
# INFO:tensorflow:loss = 3.42056e+07, step = 20215 (0.783 sec)
# INFO:tensorflow:loss = 4.02933e+07, step = 20315 (0.659 sec)
# INFO:tensorflow:loss = 4.75175e+07, step = 20415 (0.630 sec)
# INFO:tensorflow:Saving checkpoints for 20415 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.75175e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:26:05
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-20415
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:26:08
# INFO:tensorflow:Saving dict for global step 20415: accuracy = 0.761724, accuracy_baseline = 0.761441, auc = 0.579363, auc_precision_recall = 0.341021, average_loss = 0.865003, global_step = 20415, label/mean = 0.238559, loss = 8.09876e+07, prediction/mean = 0.0518331
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-20415
# INFO:tensorflow:Saving checkpoints for 20416 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 8.40186e+07, step = 20416
# INFO:tensorflow:loss = 3.79989e+07, step = 20516 (1.406 sec)
# INFO:tensorflow:loss = 3.2735e+07, step = 20616 (0.879 sec)
# INFO:tensorflow:loss = 3.12183e+07, step = 20716 (0.684 sec)
# INFO:tensorflow:loss = 2.90322e+07, step = 20816 (0.626 sec)
# INFO:tensorflow:loss = 2.78443e+07, step = 20916 (0.626 sec)
# INFO:tensorflow:loss = 3.10652e+07, step = 21016 (0.743 sec)
# INFO:tensorflow:loss = 3.27701e+07, step = 21116 (0.635 sec)
# INFO:tensorflow:loss = 3.01198e+07, step = 21216 (0.628 sec)
# INFO:tensorflow:loss = 2.8235e+07, step = 21316 (0.629 sec)
# INFO:tensorflow:loss = 3.09576e+07, step = 21416 (0.624 sec)
# INFO:tensorflow:loss = 3.06293e+07, step = 21516 (0.628 sec)
# INFO:tensorflow:loss = 3.51966e+07, step = 21616 (0.621 sec)
# INFO:tensorflow:loss = 3.16252e+07, step = 21716 (0.631 sec)
# INFO:tensorflow:loss = 2.76478e+07, step = 21816 (0.622 sec)
# INFO:tensorflow:loss = 2.93657e+07, step = 21916 (0.625 sec)
# INFO:tensorflow:loss = 2.75563e+07, step = 22016 (0.623 sec)
# INFO:tensorflow:loss = 3.05096e+07, step = 22116 (0.623 sec)
# INFO:tensorflow:loss = 3.09714e+07, step = 22216 (0.620 sec)
# INFO:tensorflow:loss = 3.63719e+07, step = 22316 (0.626 sec)
# INFO:tensorflow:loss = 3.59265e+07, step = 22416 (0.626 sec)
# INFO:tensorflow:loss = 2.77528e+07, step = 22516 (0.622 sec)
# INFO:tensorflow:loss = 2.92178e+07, step = 22616 (0.622 sec)
# INFO:tensorflow:loss = 3.29011e+07, step = 22716 (0.690 sec)
# INFO:tensorflow:loss = 3.49679e+07, step = 22816 (0.623 sec)
# INFO:tensorflow:loss = 2.91462e+07, step = 22916 (0.632 sec)
# INFO:tensorflow:loss = 3.01286e+07, step = 23016 (0.636 sec)
# INFO:tensorflow:loss = 2.7487e+07, step = 23116 (0.645 sec)
# INFO:tensorflow:loss = 3.97261e+07, step = 23216 (0.642 sec)
# INFO:tensorflow:loss = 3.71787e+07, step = 23316 (0.631 sec)
# INFO:tensorflow:loss = 3.15948e+07, step = 23416 (0.644 sec)
# INFO:tensorflow:loss = 2.89282e+07, step = 23516 (0.621 sec)
# INFO:tensorflow:loss = 3.35934e+07, step = 23616 (0.647 sec)
# INFO:tensorflow:loss = 3.39155e+07, step = 23716 (0.640 sec)
# INFO:tensorflow:loss = 3.15035e+07, step = 23816 (0.644 sec)
# INFO:tensorflow:loss = 3.18883e+07, step = 23916 (0.637 sec)
# INFO:tensorflow:loss = 2.88875e+07, step = 24016 (0.648 sec)
# INFO:tensorflow:loss = 2.69842e+07, step = 24116 (0.630 sec)
# INFO:tensorflow:loss = 2.65015e+07, step = 24216 (0.637 sec)
# INFO:tensorflow:loss = 2.75887e+07, step = 24316 (0.644 sec)
# INFO:tensorflow:loss = 3.1177e+07, step = 24416 (0.645 sec)
# INFO:tensorflow:loss = 2.68732e+07, step = 24516 (0.649 sec)
# INFO:tensorflow:loss = 3.42919e+07, step = 24616 (0.649 sec)
# INFO:tensorflow:loss = 3.08954e+07, step = 24716 (0.661 sec)
# INFO:tensorflow:loss = 3.08341e+07, step = 24816 (0.660 sec)
# INFO:tensorflow:loss = 3.18863e+07, step = 24916 (0.627 sec)
# INFO:tensorflow:loss = 3.14016e+07, step = 25016 (0.634 sec)
# INFO:tensorflow:loss = 2.78267e+07, step = 25116 (0.702 sec)
# INFO:tensorflow:loss = 3.54647e+07, step = 25216 (0.768 sec)
# INFO:tensorflow:loss = 2.59632e+07, step = 25316 (0.654 sec)
# INFO:tensorflow:global_step/sec: 150.867
# INFO:tensorflow:loss = 2.70247e+07, step = 25416 (0.638 sec)
# INFO:tensorflow:loss = 3.09478e+07, step = 25516 (0.660 sec)
# INFO:tensorflow:loss = 2.66087e+07, step = 25616 (0.639 sec)
# INFO:tensorflow:loss = 2.97572e+07, step = 25716 (0.634 sec)
# INFO:tensorflow:loss = 2.44843e+07, step = 25816 (0.647 sec)
# INFO:tensorflow:loss = 3.29221e+07, step = 25916 (0.642 sec)
# INFO:tensorflow:loss = 3.01968e+07, step = 26016 (0.643 sec)
# INFO:tensorflow:loss = 4.35707e+07, step = 26116 (0.641 sec)
# INFO:tensorflow:loss = 3.63467e+07, step = 26216 (0.676 sec)
# INFO:tensorflow:loss = 2.50737e+07, step = 26316 (0.643 sec)
# INFO:tensorflow:loss = 3.32529e+07, step = 26416 (0.641 sec)
# INFO:tensorflow:loss = 3.61204e+07, step = 26516 (0.639 sec)
# INFO:tensorflow:loss = 2.58564e+07, step = 26616 (0.631 sec)
# INFO:tensorflow:loss = 3.06533e+07, step = 26716 (0.650 sec)
# INFO:tensorflow:loss = 3.28238e+07, step = 26816 (0.626 sec)
# INFO:tensorflow:loss = 3.06827e+07, step = 26916 (0.650 sec)
# INFO:tensorflow:loss = 2.9703e+07, step = 27016 (0.649 sec)
# INFO:tensorflow:loss = 3.02996e+07, step = 27116 (0.638 sec)
# INFO:tensorflow:loss = 3.37479e+07, step = 27216 (0.646 sec)
# INFO:tensorflow:loss = 2.66664e+07, step = 27316 (0.645 sec)
# INFO:tensorflow:Saving checkpoints for 27401 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.87808e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:27:20
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-27401
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:27:23
# INFO:tensorflow:Saving dict for global step 27401: accuracy = 0.858645, accuracy_baseline = 0.761441, auc = 0.915266, auc_precision_recall = 0.785664, average_loss = 0.312174, global_step = 27401, label/mean = 0.238559, loss = 2.92279e+07, prediction/mean = 0.273082
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-27401
# INFO:tensorflow:Saving checkpoints for 27402 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.14603e+07, step = 27402
# INFO:tensorflow:loss = 3.12376e+07, step = 27502 (1.308 sec)
# INFO:tensorflow:loss = 3.21975e+07, step = 27602 (0.700 sec)
# INFO:tensorflow:loss = 2.91219e+07, step = 27702 (0.690 sec)
# INFO:tensorflow:loss = 2.98843e+07, step = 27802 (0.681 sec)
# INFO:tensorflow:loss = 2.63899e+07, step = 27902 (0.699 sec)
# INFO:tensorflow:loss = 3.02958e+07, step = 28002 (0.714 sec)
# INFO:tensorflow:loss = 3.12266e+07, step = 28102 (0.703 sec)
# INFO:tensorflow:loss = 3.09121e+07, step = 28202 (0.706 sec)
# INFO:tensorflow:loss = 2.78294e+07, step = 28302 (0.715 sec)
# INFO:tensorflow:loss = 3.11964e+07, step = 28402 (0.716 sec)
# INFO:tensorflow:loss = 2.97742e+07, step = 28502 (0.725 sec)
# INFO:tensorflow:loss = 3.33572e+07, step = 28602 (0.709 sec)
# INFO:tensorflow:loss = 3.44354e+07, step = 28702 (0.718 sec)
# INFO:tensorflow:loss = 2.79239e+07, step = 28802 (0.697 sec)
# INFO:tensorflow:loss = 2.58572e+07, step = 28902 (0.712 sec)
# INFO:tensorflow:loss = 2.63591e+07, step = 29002 (0.705 sec)
# INFO:tensorflow:loss = 2.95191e+07, step = 29102 (0.710 sec)
# INFO:tensorflow:loss = 1.28515e+08, step = 29202 (0.710 sec)
# INFO:tensorflow:loss = 2.94494e+07, step = 29302 (0.754 sec)
# INFO:tensorflow:loss = 3.43298e+07, step = 29402 (0.708 sec)
# INFO:tensorflow:loss = 2.5646e+07, step = 29502 (0.708 sec)
# INFO:tensorflow:loss = 2.69638e+07, step = 29602 (0.710 sec)
# INFO:tensorflow:loss = 3.24358e+07, step = 29702 (0.721 sec)
# INFO:tensorflow:loss = 3.50073e+07, step = 29802 (0.709 sec)
# INFO:tensorflow:loss = 2.78401e+07, step = 29902 (0.712 sec)
# INFO:tensorflow:loss = 3.10846e+07, step = 30002 (0.857 sec)
# INFO:tensorflow:loss = 2.6201e+07, step = 30102 (0.917 sec)
# INFO:tensorflow:loss = 3.64308e+07, step = 30202 (0.911 sec)
# INFO:tensorflow:loss = 3.53189e+07, step = 30302 (0.766 sec)
# INFO:tensorflow:loss = 3.17312e+07, step = 30402 (0.742 sec)
# INFO:tensorflow:loss = 2.77387e+07, step = 30502 (0.674 sec)
# INFO:tensorflow:loss = 3.10043e+07, step = 30602 (0.686 sec)
# INFO:tensorflow:loss = 3.238e+07, step = 30702 (0.684 sec)
# INFO:tensorflow:loss = 2.96855e+07, step = 30802 (0.685 sec)
# INFO:tensorflow:loss = 3.51003e+07, step = 30902 (0.681 sec)
# INFO:tensorflow:loss = 2.81437e+07, step = 31002 (0.692 sec)
# INFO:tensorflow:loss = 2.69604e+07, step = 31102 (0.680 sec)
# INFO:tensorflow:loss = 2.57806e+07, step = 31202 (0.693 sec)
# INFO:tensorflow:loss = 2.7745e+07, step = 31302 (0.674 sec)
# INFO:tensorflow:loss = 3.05767e+07, step = 31402 (0.693 sec)
# INFO:tensorflow:loss = 3.44714e+07, step = 31502 (0.680 sec)
# INFO:tensorflow:loss = 2.73246e+07, step = 31602 (0.688 sec)
# INFO:tensorflow:loss = 2.96931e+07, step = 31702 (0.704 sec)
# INFO:tensorflow:loss = 3.23169e+07, step = 31802 (0.699 sec)
# INFO:tensorflow:loss = 2.73031e+07, step = 31902 (0.684 sec)
# INFO:tensorflow:loss = 3.02641e+07, step = 32002 (0.712 sec)
# INFO:tensorflow:loss = 2.61099e+07, step = 32102 (0.677 sec)
# INFO:tensorflow:loss = 2.92053e+07, step = 32202 (0.695 sec)
# INFO:tensorflow:loss = 2.97349e+07, step = 32302 (0.685 sec)
# INFO:tensorflow:global_step/sec: 137.785
# INFO:tensorflow:loss = 3.16498e+07, step = 32402 (0.690 sec)
# INFO:tensorflow:loss = 2.7229e+07, step = 32502 (0.687 sec)
# INFO:tensorflow:loss = 2.74572e+07, step = 32602 (0.701 sec)
# INFO:tensorflow:loss = 3.11997e+07, step = 32702 (0.682 sec)
# INFO:tensorflow:loss = 2.26085e+07, step = 32802 (0.714 sec)
# INFO:tensorflow:loss = 3.19536e+07, step = 32902 (0.723 sec)
# INFO:tensorflow:loss = 3.48984e+07, step = 33002 (0.686 sec)
# INFO:tensorflow:loss = 3.47855e+07, step = 33102 (0.688 sec)
# INFO:tensorflow:loss = 3.46503e+07, step = 33202 (0.705 sec)
# INFO:tensorflow:loss = 2.96276e+07, step = 33302 (0.686 sec)
# INFO:tensorflow:loss = 3.19864e+07, step = 33402 (0.695 sec)
# INFO:tensorflow:loss = 3.73658e+07, step = 33502 (0.735 sec)
# INFO:tensorflow:loss = 2.58759e+07, step = 33602 (0.682 sec)
# INFO:tensorflow:loss = 3.00309e+07, step = 33702 (0.688 sec)
# INFO:tensorflow:Saving checkpoints for 33765 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.7769e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:28:34
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-33765
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:28:36
# INFO:tensorflow:Saving dict for global step 33765: accuracy = 0.856768, accuracy_baseline = 0.761441, auc = 0.91499, auc_precision_recall = 0.784547, average_loss = 0.318845, global_step = 33765, label/mean = 0.238559, loss = 2.98524e+07, prediction/mean = 0.286305
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-33765
# INFO:tensorflow:Saving checkpoints for 33766 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.22032e+07, step = 33766
# INFO:tensorflow:loss = 2.97057e+07, step = 33866 (1.102 sec)
# INFO:tensorflow:loss = 3.09131e+07, step = 33966 (0.639 sec)
# INFO:tensorflow:loss = 2.89392e+07, step = 34066 (0.636 sec)
# INFO:tensorflow:loss = 2.72395e+07, step = 34166 (0.632 sec)
# INFO:tensorflow:loss = 2.68295e+07, step = 34266 (0.657 sec)
# INFO:tensorflow:loss = 3.17194e+07, step = 34366 (0.638 sec)
# INFO:tensorflow:loss = 2.9987e+07, step = 34466 (0.634 sec)
# INFO:tensorflow:loss = 2.77053e+07, step = 34566 (0.633 sec)
# INFO:tensorflow:loss = 2.7082e+07, step = 34666 (0.634 sec)
# INFO:tensorflow:loss = 2.85154e+07, step = 34766 (0.630 sec)
# INFO:tensorflow:loss = 2.94007e+07, step = 34866 (0.635 sec)
# INFO:tensorflow:loss = 3.91131e+07, step = 34966 (0.630 sec)
# INFO:tensorflow:loss = 3.55951e+07, step = 35066 (0.633 sec)
# INFO:tensorflow:loss = 2.74032e+07, step = 35166 (0.628 sec)
# INFO:tensorflow:loss = 2.50905e+07, step = 35266 (0.645 sec)
# INFO:tensorflow:loss = 2.53771e+07, step = 35366 (0.639 sec)
# INFO:tensorflow:loss = 3.19944e+07, step = 35466 (0.642 sec)
# INFO:tensorflow:loss = 3.38637e+07, step = 35566 (0.669 sec)
# INFO:tensorflow:loss = 3.03127e+07, step = 35666 (0.636 sec)
# INFO:tensorflow:loss = 3.1843e+07, step = 35766 (0.630 sec)
# INFO:tensorflow:loss = 2.78535e+07, step = 35866 (0.632 sec)
# INFO:tensorflow:loss = 2.72455e+07, step = 35966 (0.633 sec)
# INFO:tensorflow:loss = 3.2296e+07, step = 36066 (0.652 sec)
# INFO:tensorflow:loss = 3.54603e+07, step = 36166 (0.630 sec)
# INFO:tensorflow:loss = 2.74788e+07, step = 36266 (0.634 sec)
# INFO:tensorflow:loss = 3.20545e+07, step = 36366 (0.628 sec)
# INFO:tensorflow:loss = 2.83648e+07, step = 36466 (0.628 sec)
# INFO:tensorflow:loss = 3.31156e+07, step = 36566 (0.631 sec)
# INFO:tensorflow:loss = 3.30347e+07, step = 36666 (0.629 sec)
# INFO:tensorflow:loss = 3.55235e+07, step = 36766 (0.638 sec)
# INFO:tensorflow:loss = 2.82983e+07, step = 36866 (0.621 sec)
# INFO:tensorflow:loss = 3.00302e+07, step = 36966 (0.644 sec)
# INFO:tensorflow:loss = 4.02104e+07, step = 37066 (0.633 sec)
# INFO:tensorflow:loss = 2.94086e+07, step = 37166 (0.633 sec)
# INFO:tensorflow:loss = 3.18232e+07, step = 37266 (0.635 sec)
# INFO:tensorflow:loss = 2.9796e+07, step = 37366 (0.744 sec)
# INFO:tensorflow:loss = 2.95468e+07, step = 37466 (0.630 sec)
# INFO:tensorflow:loss = 2.58925e+07, step = 37566 (0.613 sec)
# INFO:tensorflow:loss = 2.89826e+07, step = 37666 (0.607 sec)
# INFO:tensorflow:loss = 3.18956e+07, step = 37766 (0.613 sec)
# INFO:tensorflow:loss = 2.58762e+07, step = 37866 (0.610 sec)
# INFO:tensorflow:loss = 2.73165e+07, step = 37966 (0.610 sec)
# INFO:tensorflow:loss = 3.29913e+07, step = 38066 (0.610 sec)
# INFO:tensorflow:loss = 3.20996e+07, step = 38166 (0.615 sec)
# INFO:tensorflow:loss = 2.79571e+07, step = 38266 (0.615 sec)
# INFO:tensorflow:loss = 3.37568e+07, step = 38366 (0.612 sec)
# INFO:tensorflow:loss = 2.59226e+07, step = 38466 (0.613 sec)
# INFO:tensorflow:loss = 3.16986e+07, step = 38566 (0.611 sec)
# INFO:tensorflow:loss = 2.51484e+07, step = 38666 (0.609 sec)
# INFO:tensorflow:global_step/sec: 156.005
# INFO:tensorflow:loss = 2.52346e+07, step = 38766 (0.616 sec)
# INFO:tensorflow:loss = 2.54951e+07, step = 38866 (0.609 sec)
# INFO:tensorflow:loss = 2.74047e+07, step = 38966 (0.612 sec)
# INFO:tensorflow:loss = 2.99081e+07, step = 39066 (0.629 sec)
# INFO:tensorflow:loss = 2.72235e+07, step = 39166 (0.612 sec)
# INFO:tensorflow:loss = 3.40064e+07, step = 39266 (0.607 sec)
# INFO:tensorflow:loss = 2.91047e+07, step = 39366 (0.627 sec)
# INFO:tensorflow:loss = 3.75475e+07, step = 39466 (0.613 sec)
# INFO:tensorflow:loss = 3.37665e+07, step = 39566 (0.609 sec)
# INFO:tensorflow:loss = 2.81087e+07, step = 39666 (0.616 sec)
# INFO:tensorflow:loss = 3.08062e+07, step = 39766 (0.612 sec)
# INFO:tensorflow:loss = 3.55825e+07, step = 39866 (0.618 sec)
# INFO:tensorflow:loss = 2.56939e+07, step = 39966 (0.603 sec)
# INFO:tensorflow:loss = 3.08249e+07, step = 40066 (0.617 sec)
# INFO:tensorflow:loss = 2.91578e+07, step = 40166 (0.619 sec)
# INFO:tensorflow:loss = 3.13009e+07, step = 40266 (0.645 sec)
# INFO:tensorflow:loss = 2.92362e+07, step = 40366 (0.629 sec)
# INFO:tensorflow:loss = 3.09745e+07, step = 40466 (0.666 sec)
# INFO:tensorflow:loss = 3.21187e+07, step = 40566 (0.621 sec)
# INFO:tensorflow:loss = 2.64925e+07, step = 40666 (0.629 sec)
# INFO:tensorflow:loss = 2.64858e+07, step = 40766 (0.771 sec)
# INFO:tensorflow:loss = 3.27026e+07, step = 40866 (0.686 sec)
# INFO:tensorflow:loss = 2.58593e+07, step = 40966 (0.835 sec)
# INFO:tensorflow:loss = 2.97914e+07, step = 41066 (0.652 sec)
# INFO:tensorflow:loss = 5.52963e+07, step = 41166 (0.714 sec)
# INFO:tensorflow:loss = 3.28582e+07, step = 41266 (0.618 sec)
# INFO:tensorflow:Saving checkpoints for 41275 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.89945e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:29:47
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-41275
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:29:49
# INFO:tensorflow:Saving dict for global step 41275: accuracy = 0.858083, accuracy_baseline = 0.761441, auc = 0.915439, auc_precision_recall = 0.78594, average_loss = 0.310549, global_step = 41275, label/mean = 0.238559, loss = 2.90758e+07, prediction/mean = 0.227204
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-41275
# INFO:tensorflow:Saving checkpoints for 41276 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.15346e+07, step = 41276
# INFO:tensorflow:loss = 3.07187e+07, step = 41376 (1.262 sec)
# INFO:tensorflow:loss = 3.25912e+07, step = 41476 (0.679 sec)
# INFO:tensorflow:loss = 2.87063e+07, step = 41576 (0.678 sec)
# INFO:tensorflow:loss = 2.66451e+07, step = 41676 (0.668 sec)
# INFO:tensorflow:loss = 2.71033e+07, step = 41776 (0.828 sec)
# INFO:tensorflow:loss = 2.96147e+07, step = 41876 (0.792 sec)
# INFO:tensorflow:loss = 2.77691e+07, step = 41976 (0.750 sec)
# INFO:tensorflow:loss = 2.71483e+07, step = 42076 (0.748 sec)
# INFO:tensorflow:loss = 3.08104e+07, step = 42176 (0.739 sec)
# INFO:tensorflow:loss = 3.14236e+07, step = 42276 (0.721 sec)
# INFO:tensorflow:loss = 2.94911e+07, step = 42376 (0.679 sec)
# INFO:tensorflow:loss = 2.97291e+07, step = 42476 (0.674 sec)
# INFO:tensorflow:loss = 2.98922e+07, step = 42576 (0.707 sec)
# INFO:tensorflow:loss = 2.6375e+07, step = 42676 (0.788 sec)
# INFO:tensorflow:loss = 2.46832e+07, step = 42776 (1.094 sec)
# INFO:tensorflow:loss = 2.74917e+07, step = 42876 (0.958 sec)
# INFO:tensorflow:loss = 2.80412e+07, step = 42976 (0.700 sec)
# INFO:tensorflow:loss = 2.91016e+07, step = 43076 (1.045 sec)
# INFO:tensorflow:loss = 3.03261e+07, step = 43176 (1.129 sec)
# INFO:tensorflow:loss = 3.18039e+07, step = 43276 (0.832 sec)
# INFO:tensorflow:loss = 2.49262e+07, step = 43376 (0.854 sec)
# INFO:tensorflow:loss = 2.64329e+07, step = 43476 (0.943 sec)
# INFO:tensorflow:loss = 3.25148e+07, step = 43576 (0.992 sec)
# INFO:tensorflow:loss = 3.36647e+07, step = 43676 (0.825 sec)
# INFO:tensorflow:loss = 2.71566e+07, step = 43776 (0.796 sec)
# INFO:tensorflow:loss = 3.4066e+07, step = 43876 (0.705 sec)
# INFO:tensorflow:loss = 2.7138e+07, step = 43976 (0.629 sec)
# INFO:tensorflow:loss = 3.09876e+07, step = 44076 (0.624 sec)
# INFO:tensorflow:loss = 2.9971e+07, step = 44176 (0.614 sec)
# INFO:tensorflow:loss = 3.03271e+07, step = 44276 (0.638 sec)
# INFO:tensorflow:loss = 2.7475e+07, step = 44376 (0.627 sec)
# INFO:tensorflow:loss = 2.82595e+07, step = 44476 (0.639 sec)
# INFO:tensorflow:loss = 3.16736e+07, step = 44576 (0.619 sec)
# INFO:tensorflow:loss = 3.23281e+07, step = 44676 (0.631 sec)
# INFO:tensorflow:loss = 3.30919e+07, step = 44776 (0.617 sec)
# INFO:tensorflow:loss = 2.75372e+07, step = 44876 (0.620 sec)
# INFO:tensorflow:loss = 3.57407e+07, step = 44976 (0.621 sec)
# INFO:tensorflow:loss = 2.58776e+07, step = 45076 (0.625 sec)
# INFO:tensorflow:loss = 2.84288e+07, step = 45176 (0.616 sec)
# INFO:tensorflow:loss = 3.30069e+07, step = 45276 (0.622 sec)
# INFO:tensorflow:loss = 2.64358e+07, step = 45376 (0.620 sec)
# INFO:tensorflow:loss = 2.8023e+07, step = 45476 (0.627 sec)
# INFO:tensorflow:loss = 3.35599e+07, step = 45576 (0.614 sec)
# INFO:tensorflow:loss = 3.27421e+07, step = 45676 (0.625 sec)
# INFO:tensorflow:loss = 2.95219e+07, step = 45776 (0.659 sec)
# INFO:tensorflow:loss = 3.3239e+07, step = 45876 (0.622 sec)
# INFO:tensorflow:loss = 2.60163e+07, step = 45976 (0.615 sec)
# INFO:tensorflow:loss = 3.35639e+07, step = 46076 (0.626 sec)
# INFO:tensorflow:loss = 2.5412e+07, step = 46176 (0.620 sec)
# INFO:tensorflow:global_step/sec: 136.699
# INFO:tensorflow:loss = 2.87357e+07, step = 46276 (0.621 sec)
# INFO:tensorflow:loss = 2.71477e+07, step = 46376 (0.617 sec)
# INFO:tensorflow:loss = 2.66894e+07, step = 46476 (0.620 sec)
# INFO:tensorflow:loss = 3.00499e+07, step = 46576 (0.618 sec)
# INFO:tensorflow:loss = 2.39312e+07, step = 46676 (0.621 sec)
# INFO:tensorflow:loss = 3.67604e+07, step = 46776 (0.752 sec)
# INFO:tensorflow:loss = 3.19913e+07, step = 46876 (0.640 sec)
# INFO:tensorflow:loss = 3.29410e+07, step = 46976 (0.624 sec)
# INFO:tensorflow:loss = 3.44895e+07, step = 47076 (0.623 sec)
# INFO:tensorflow:loss = 2.40729e+07, step = 47176 (0.622 sec)
# INFO:tensorflow:loss = 3.11999e+07, step = 47276 (0.618 sec)
# INFO:tensorflow:loss = 3.60357e+07, step = 47376 (0.629 sec)
# INFO:tensorflow:Saving checkpoints for 47414 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.72878e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:31:00
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-47414
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:31:03
# INFO:tensorflow:Saving dict for global step 47414: accuracy = 0.862487, accuracy_baseline = 0.761441, auc = 0.919099, auc_precision_recall = 0.791409, average_loss = 0.303918, global_step = 47414, label/mean = 0.238559, loss = 2.84549e+07, prediction/mean = 0.26262
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-47414
# INFO:tensorflow:Saving checkpoints for 47415 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.07011e+07, step = 47415
# INFO:tensorflow:loss = 3.03404e+07, step = 47515 (1.258 sec)
# INFO:tensorflow:loss = 3.1899e+07, step = 47615 (0.673 sec)
# INFO:tensorflow:loss = 2.87524e+07, step = 47715 (0.669 sec)
# INFO:tensorflow:loss = 2.69482e+07, step = 47815 (0.675 sec)
# INFO:tensorflow:loss = 2.59681e+07, step = 47915 (0.676 sec)
# INFO:tensorflow:loss = 2.96134e+07, step = 48015 (0.679 sec)
# INFO:tensorflow:loss = 2.80249e+07, step = 48115 (0.714 sec)
# INFO:tensorflow:loss = 2.80511e+07, step = 48215 (0.687 sec)
# INFO:tensorflow:loss = 2.98108e+07, step = 48315 (0.675 sec)
# INFO:tensorflow:loss = 2.81129e+07, step = 48415 (0.665 sec)
# INFO:tensorflow:loss = 2.87179e+07, step = 48515 (0.670 sec)
# INFO:tensorflow:loss = 2.80897e+07, step = 48615 (0.692 sec)
# INFO:tensorflow:loss = 2.94615e+07, step = 48715 (0.685 sec)
# INFO:tensorflow:loss = 3.15687e+07, step = 48815 (0.677 sec)
# INFO:tensorflow:loss = 2.51278e+07, step = 48915 (0.685 sec)
# INFO:tensorflow:loss = 2.90625e+07, step = 49015 (0.667 sec)
# INFO:tensorflow:loss = 2.77414e+07, step = 49115 (0.675 sec)
# INFO:tensorflow:loss = 2.91864e+07, step = 49215 (0.662 sec)
# INFO:tensorflow:loss = 2.80991e+07, step = 49315 (0.663 sec)
# INFO:tensorflow:loss = 3.14047e+07, step = 49415 (0.670 sec)
# INFO:tensorflow:loss = 2.68545e+07, step = 49515 (0.710 sec)
# INFO:tensorflow:loss = 2.60171e+07, step = 49615 (0.669 sec)
# INFO:tensorflow:loss = 3.18573e+07, step = 49715 (0.668 sec)
# INFO:tensorflow:loss = 3.49564e+07, step = 49815 (0.685 sec)
# INFO:tensorflow:loss = 2.66509e+07, step = 49915 (0.678 sec)
# INFO:tensorflow:loss = 3.71196e+07, step = 50015 (0.679 sec)
# INFO:tensorflow:loss = 2.58288e+07, step = 50115 (0.661 sec)
# INFO:tensorflow:loss = 3.1506e+07, step = 50215 (0.674 sec)
# INFO:tensorflow:loss = 2.98719e+07, step = 50315 (0.678 sec)
# INFO:tensorflow:loss = 3.08552e+07, step = 50415 (0.673 sec)
# INFO:tensorflow:loss = 2.71668e+07, step = 50515 (0.664 sec)
# INFO:tensorflow:loss = 2.88109e+07, step = 50615 (0.679 sec)
# INFO:tensorflow:loss = 3.00956e+07, step = 50715 (0.675 sec)
# INFO:tensorflow:loss = 2.9023e+07, step = 50815 (0.682 sec)
# INFO:tensorflow:loss = 3.0072e+07, step = 50915 (0.671 sec)
# INFO:tensorflow:loss = 2.66321e+07, step = 51015 (0.714 sec)
# INFO:tensorflow:loss = 2.68917e+07, step = 51115 (0.672 sec)
# INFO:tensorflow:loss = 2.62654e+07, step = 51215 (0.683 sec)
# INFO:tensorflow:loss = 2.78177e+07, step = 51315 (0.676 sec)
# INFO:tensorflow:loss = 2.88108e+07, step = 51415 (0.693 sec)
# INFO:tensorflow:loss = 2.56254e+07, step = 51515 (0.678 sec)
# INFO:tensorflow:loss = 2.96947e+07, step = 51615 (0.688 sec)
# INFO:tensorflow:loss = 2.96037e+07, step = 51715 (0.681 sec)
# INFO:tensorflow:loss = 2.97962e+07, step = 51815 (0.683 sec)
# INFO:tensorflow:loss = 3.15534e+07, step = 51915 (0.688 sec)
# INFO:tensorflow:loss = 2.94362e+07, step = 52015 (0.681 sec)
# INFO:tensorflow:loss = 2.87091e+07, step = 52115 (0.669 sec)
# INFO:tensorflow:loss = 3.1292e+07, step = 52215 (0.679 sec)
# INFO:tensorflow:loss = 2.51968e+07, step = 52315 (0.701 sec)
# INFO:tensorflow:global_step/sec: 144.835
# INFO:tensorflow:loss = 2.43618e+07, step = 52415 (0.676 sec)
# INFO:tensorflow:loss = 2.48532e+07, step = 52515 (0.703 sec)
# INFO:tensorflow:loss = 2.52918e+07, step = 52615 (0.685 sec)
# INFO:tensorflow:loss = 3.10356e+07, step = 52715 (0.678 sec)
# INFO:tensorflow:loss = 2.21702e+07, step = 52815 (0.698 sec)
# INFO:tensorflow:loss = 3.20212e+07, step = 52915 (0.671 sec)
# INFO:tensorflow:loss = 2.72997e+07, step = 53015 (0.697 sec)
# INFO:tensorflow:loss = 3.22148e+07, step = 53115 (0.675 sec)
# INFO:tensorflow:loss = 3.44765e+07, step = 53215 (0.674 sec)
# INFO:tensorflow:loss = 2.34586e+07, step = 53315 (0.674 sec)
# INFO:tensorflow:loss = 3.06289e+07, step = 53415 (0.676 sec)
# INFO:tensorflow:loss = 3.4327e+07, step = 53515 (0.682 sec)
# INFO:tensorflow:loss = 2.49605e+07, step = 53615 (0.676 sec)
# INFO:tensorflow:loss = 2.92301e+07, step = 53715 (0.688 sec)
# INFO:tensorflow:loss = 3.29257e+07, step = 53815 (0.664 sec)
# INFO:tensorflow:loss = 2.91582e+07, step = 53915 (0.674 sec)
# INFO:tensorflow:loss = 3.05725e+07, step = 54015 (0.670 sec)
# INFO:tensorflow:Saving checkpoints for 54103 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.04974e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:32:13
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-54103
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:32:16
# INFO:tensorflow:Saving dict for global step 54103: accuracy = 0.86102, accuracy_baseline = 0.761441, auc = 0.921146, auc_precision_recall = 0.79693, average_loss = 0.294619, global_step = 54103, label/mean = 0.238559, loss = 2.75842e+07, prediction/mean = 0.242197
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-54103
# INFO:tensorflow:Saving checkpoints for 54104 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.00771e+07, step = 54104
# INFO:tensorflow:loss = 2.91228e+07, step = 54204 (1.291 sec)
# INFO:tensorflow:loss = 3.05175e+07, step = 54304 (0.710 sec)
# INFO:tensorflow:loss = 2.81834e+07, step = 54404 (0.694 sec)
# INFO:tensorflow:loss = 2.7101e+07, step = 54504 (0.677 sec)
# INFO:tensorflow:loss = 2.51999e+07, step = 54604 (0.664 sec)
# INFO:tensorflow:loss = 2.92559e+07, step = 54704 (0.713 sec)
# INFO:tensorflow:loss = 2.71763e+07, step = 54804 (0.651 sec)
# INFO:tensorflow:loss = 2.78297e+07, step = 54904 (0.643 sec)
# INFO:tensorflow:loss = 2.78281e+07, step = 55004 (0.649 sec)
# INFO:tensorflow:loss = 2.66654e+07, step = 55104 (0.728 sec)
# INFO:tensorflow:loss = 2.81662e+07, step = 55204 (0.840 sec)
# INFO:tensorflow:loss = 2.71252e+07, step = 55304 (0.892 sec)
# INFO:tensorflow:loss = 2.89076e+07, step = 55404 (1.000 sec)
# INFO:tensorflow:loss = 2.62601e+07, step = 55504 (0.650 sec)
# INFO:tensorflow:loss = 2.4966e+07, step = 55604 (0.775 sec)
# INFO:tensorflow:loss = 2.56429e+07, step = 55704 (0.780 sec)
# INFO:tensorflow:loss = 2.67861e+07, step = 55804 (0.622 sec)
# INFO:tensorflow:loss = 2.83947e+07, step = 55904 (0.619 sec)
# INFO:tensorflow:loss = 2.7648e+07, step = 56004 (0.616 sec)
# INFO:tensorflow:loss = 3.04433e+07, step = 56104 (0.618 sec)
# INFO:tensorflow:loss = 2.50677e+07, step = 56204 (0.625 sec)
# INFO:tensorflow:loss = 2.62647e+07, step = 56304 (0.619 sec)
# INFO:tensorflow:loss = 3.14891e+07, step = 56404 (0.621 sec)
# INFO:tensorflow:loss = 3.28722e+07, step = 56504 (0.629 sec)
# INFO:tensorflow:loss = 2.63793e+07, step = 56604 (0.776 sec)
# INFO:tensorflow:loss = 3.27242e+07, step = 56704 (0.638 sec)
# INFO:tensorflow:loss = 2.57441e+07, step = 56804 (0.644 sec)
# INFO:tensorflow:loss = 3.09908e+07, step = 56904 (0.625 sec)
# INFO:tensorflow:loss = 2.94912e+07, step = 57004 (0.612 sec)
# INFO:tensorflow:loss = 3.08605e+07, step = 57104 (0.627 sec)
# INFO:tensorflow:loss = 2.69759e+07, step = 57204 (0.607 sec)
# INFO:tensorflow:loss = 2.73574e+07, step = 57304 (0.673 sec)
# INFO:tensorflow:loss = 2.95893e+07, step = 57404 (0.662 sec)
# INFO:tensorflow:loss = 2.85481e+07, step = 57504 (0.683 sec)
# INFO:tensorflow:loss = 2.9541e+07, step = 57604 (0.661 sec)
# INFO:tensorflow:loss = 2.69958e+07, step = 57704 (0.648 sec)
# INFO:tensorflow:loss = 2.76578e+07, step = 57804 (0.642 sec)
# INFO:tensorflow:loss = 2.48845e+07, step = 57904 (0.627 sec)
# INFO:tensorflow:loss = 2.77166e+07, step = 58004 (0.650 sec)
# INFO:tensorflow:loss = 2.69366e+07, step = 58104 (0.623 sec)
# INFO:tensorflow:loss = 2.479e+07, step = 58204 (0.621 sec)
# INFO:tensorflow:loss = 2.78215e+07, step = 58304 (0.621 sec)
# INFO:tensorflow:loss = 2.97264e+07, step = 58404 (0.616 sec)
# INFO:tensorflow:loss = 2.90971e+07, step = 58504 (0.620 sec)
# INFO:tensorflow:loss = 2.74542e+07, step = 58604 (0.617 sec)
# INFO:tensorflow:loss = 2.8967e+07, step = 58704 (0.629 sec)
# INFO:tensorflow:loss = 2.62894e+07, step = 58804 (0.632 sec)
# INFO:tensorflow:loss = 2.8782e+07, step = 58904 (0.619 sec)
# INFO:tensorflow:loss = 2.54577e+07, step = 59004 (0.614 sec)
# INFO:tensorflow:global_step/sec: 147.364
# INFO:tensorflow:loss = 2.52461e+07, step = 59104 (0.619 sec)
# INFO:tensorflow:loss = 2.49954e+07, step = 59204 (0.619 sec)
# INFO:tensorflow:loss = 2.46907e+07, step = 59304 (0.622 sec)
# INFO:tensorflow:loss = 2.97552e+07, step = 59404 (0.617 sec)
# INFO:tensorflow:loss = 2.21451e+07, step = 59504 (0.618 sec)
# INFO:tensorflow:loss = 3.15729e+07, step = 59604 (0.626 sec)
# INFO:tensorflow:loss = 2.72455e+07, step = 59704 (0.616 sec)
# INFO:tensorflow:loss = 3.1746e+07, step = 59804 (0.615 sec)
# INFO:tensorflow:loss = 3.39813e+07, step = 59904 (0.659 sec)
# INFO:tensorflow:loss = 2.41026e+07, step = 60004 (0.640 sec)
# INFO:tensorflow:loss = 3.00504e+07, step = 60104 (0.626 sec)
# INFO:tensorflow:loss = 3.35511e+07, step = 60204 (0.648 sec)
# INFO:tensorflow:loss = 2.52161e+07, step = 60304 (0.680 sec)
# INFO:tensorflow:loss = 2.87031e+07, step = 60404 (0.653 sec)
# INFO:tensorflow:loss = 3.03188e+07, step = 60504 (0.607 sec)
# INFO:tensorflow:loss = 3.05473e+07, step = 60604 (0.629 sec)
# INFO:tensorflow:loss = 2.85443e+07, step = 60704 (0.658 sec)
# INFO:tensorflow:loss = 2.92999e+07, step = 60804 (0.657 sec)
# INFO:tensorflow:Saving checkpoints for 60808 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.72772e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:33:28
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-60808
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:33:32
# INFO:tensorflow:Saving dict for global step 60808: accuracy = 0.860106, accuracy_baseline = 0.761441, auc = 0.919945, auc_precision_recall = 0.795851, average_loss = 0.297746, global_step = 60808, label/mean = 0.238559, loss = 2.78770e+07, prediction/mean = 0.258422
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-60808
# INFO:tensorflow:Saving checkpoints for 60809 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 2.98558e+07, step = 60809
# INFO:tensorflow:loss = 2.97561e+07, step = 60909 (1.351 sec)
# INFO:tensorflow:loss = 3.06723e+07, step = 61009 (0.778 sec)
# INFO:tensorflow:loss = 2.78739e+07, step = 61109 (0.655 sec)
# INFO:tensorflow:loss = 2.61591e+07, step = 61209 (0.625 sec)
# INFO:tensorflow:loss = 2.54042e+07, step = 61309 (0.667 sec)
# INFO:tensorflow:loss = 3.13349e+07, step = 61409 (0.631 sec)
# INFO:tensorflow:loss = 2.88309e+07, step = 61509 (0.633 sec)
# INFO:tensorflow:loss = 2.54539e+07, step = 61609 (0.620 sec)
# INFO:tensorflow:loss = 2.73787e+07, step = 61709 (0.625 sec)
# INFO:tensorflow:loss = 2.63387e+07, step = 61809 (0.621 sec)
# INFO:tensorflow:loss = 2.84528e+07, step = 61909 (0.626 sec)
# INFO:tensorflow:loss = 2.86117e+07, step = 62009 (0.623 sec)
# INFO:tensorflow:loss = 2.8486e+07, step = 62109 (0.627 sec)
# INFO:tensorflow:loss = 2.67e+07, step = 62209 (0.619 sec)
# INFO:tensorflow:loss = 2.44365e+07, step = 62309 (0.626 sec)
# INFO:tensorflow:loss = 2.4249e+07, step = 62409 (0.623 sec)
# INFO:tensorflow:loss = 2.71835e+07, step = 62509 (0.744 sec)
# INFO:tensorflow:loss = 2.85429e+07, step = 62609 (0.704 sec)
# INFO:tensorflow:loss = 2.65406e+07, step = 62709 (1.085 sec)
# INFO:tensorflow:loss = 3.06317e+07, step = 62809 (0.985 sec)
# INFO:tensorflow:loss = 2.47769e+07, step = 62909 (0.687 sec)
# INFO:tensorflow:loss = 2.6125e+07, step = 63009 (0.644 sec)
# INFO:tensorflow:loss = 3.04107e+07, step = 63109 (0.766 sec)
# INFO:tensorflow:loss = 3.35834e+07, step = 63209 (0.664 sec)
# INFO:tensorflow:loss = 2.6386e+07, step = 63309 (0.828 sec)
# INFO:tensorflow:loss = 3.12314e+07, step = 63409 (0.626 sec)
# INFO:tensorflow:loss = 2.62869e+07, step = 63509 (0.619 sec)
# INFO:tensorflow:loss = 2.99749e+07, step = 63609 (0.627 sec)
# INFO:tensorflow:loss = 2.93683e+07, step = 63709 (0.620 sec)
# INFO:tensorflow:loss = 3.05562e+07, step = 63809 (0.626 sec)
# INFO:tensorflow:loss = 2.6612e+07, step = 63909 (0.616 sec)
# INFO:tensorflow:loss = 2.70299e+07, step = 64009 (0.637 sec)
# INFO:tensorflow:loss = 2.86313e+07, step = 64109 (0.643 sec)
# INFO:tensorflow:loss = 2.80059e+07, step = 64209 (0.624 sec)
# INFO:tensorflow:loss = 2.92145e+07, step = 64309 (0.637 sec)
# INFO:tensorflow:loss = 2.69916e+07, step = 64409 (0.627 sec)
# INFO:tensorflow:loss = 2.63788e+07, step = 64509 (0.628 sec)
# INFO:tensorflow:loss = 2.48187e+07, step = 64609 (0.625 sec)
# INFO:tensorflow:loss = 2.70196e+07, step = 64709 (0.640 sec)
# INFO:tensorflow:loss = 2.65211e+07, step = 64809 (0.669 sec)
# INFO:tensorflow:loss = 2.49895e+07, step = 64909 (0.628 sec)
# INFO:tensorflow:loss = 2.75459e+07, step = 65009 (0.628 sec)
# INFO:tensorflow:loss = 2.76776e+07, step = 65109 (0.627 sec)
# INFO:tensorflow:Saving checkpoints for 65122 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.72955e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:34:28
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-65122
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:34:31
# INFO:tensorflow:Saving dict for global step 65122: accuracy = 0.863088, accuracy_baseline = 0.761441, auc = 0.922686, auc_precision_recall = 0.800468, average_loss = 0.29126, global_step = 65122, label/mean = 0.238559, loss = 2.72698e+07, prediction/mean = 0.235266
# .......................................
# Experiment finished at 23:34:31
#
# Experiment elapsed time: 734.250337 seconds

# %% [markdown]
# ## Evaluate the Model

# %%
TRAIN_SIZE = TRAIN_DATA_SIZE
TEST_SIZE = TEST_DATA_SIZE

train_input_fn = lambda: csv_input_fn(files_name_pattern= TRAIN_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TRAIN_SIZE)

test_input_fn = lambda: csv_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TEST_SIZE)

estimator = create_DNNComb_estimator(run_config, hparams)

train_results = estimator.evaluate(input_fn=train_input_fn, steps=1)
print()
print("######################################################################################")
print("# Train Measures: {}".format(train_results))
print("######################################################################################")

test_results = estimator.evaluate(input_fn=test_input_fn, steps=1)
print()
print("######################################################################################")
print("# Test Measures: {}".format(test_results))
print("######################################################################################")
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'trained_models/cenus-model-01', '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 5000, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11f1dd748>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 32561
# Epoch Count: None
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:34:38
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-65122
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:34:41
# INFO:tensorflow:Saving dict for global step 65122: accuracy = 0.863087, accuracy_baseline = 0.761441, auc = 0.922686, auc_precision_recall = 0.800468, average_loss = 0.29126, global_step = 65122, label/mean = 0.238559, loss = 1.79981e+09, prediction/mean = 0.235265
#
# ######################################################################################
# # Train Measures: {'accuracy': 0.86308742, 'accuracy_baseline': 0.76144063, 'auc': 0.9226855, 'auc_precision_recall': 0.80046827, 'average_loss': 0.29126033, 'label/mean': 0.23855937, 'loss': 1.7998065e+09, 'prediction/mean': 0.23526548, 'global_step': 65122}
# ######################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/adult.test.csv
# Batch size: 16278
# Epoch Count: None
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-23:34:45
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-65122
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-12-18-23:34:47
# INFO:tensorflow:Saving dict for global step 65122: accuracy = 0.854914, accuracy_baseline = 0.763804, auc = 0.906335, auc_precision_recall = 0.77032, average_loss = 0.315663, global_step = 65122, label/mean = 0.236196, loss = 9.73364e+08, prediction/mean = 0.233908
#
# ######################################################################################
# # Test Measures: {'accuracy': 0.85491413, 'accuracy_baseline': 0.76380354, 'auc': 0.90633488, 'auc_precision_recall': 0.77032048, 'average_loss': 0.31566253, 'label/mean': 0.23619646, 'loss': 9.7336429e+08, 'prediction/mean': 0.23390828, 'global_step': 65122}
# ######################################################################################

# %% [markdown]
# ## Prediction

# %%
import itertools

predict_input_fn = lambda: csv_input_fn(TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.PREDICT,
                                      batch_size= 10)


predictions = list(itertools.islice(estimator.predict(input_fn=predict_input_fn),10))

print("")
print("* Predicted Classes: {}".format(list(map(lambda item: item["class_ids"][0]
    ,predictions))))

print("* Predicted Probabilities: {}".format(list(map(lambda item: list(item["probabilities"])
    ,predictions))))
# Out:
# * data input_fn:
# ================
# Input file(s): data/adult.test.csv
# Batch size: 10
# Epoch Count: None
# Mode: infer
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Input graph does not contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-65122
#
# * Predicted Classes: [0, 0, 0, 1, 0, 0, 0, 1, 0, 0]
# * Predicted Probabilities: [[0.99751943, 0.002480583], [0.93063581, 0.06936422], [0.68528271, 0.31471729], [0.096927784, 0.90307224], [0.99360067, 0.006399354], [0.99461657, 0.0053833956], [0.99565083, 0.0043491907], [0.37247515, 0.62752485], [0.9979977, 0.0020023116], [0.94563544, 0.054364558]]
