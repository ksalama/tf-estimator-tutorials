# %% [markdown]
# ## UCI Adult Data Set
# ### Dataset URL: https://archive.ics.uci.edu/ml/datasets/adult
# Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset.

# %%
import shutil
import math
from datetime import datetime
import multiprocessing

import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow import data
from tensorflow.python.feature_column import feature_column

print(tf.__version__)
# Out:
# /Users/khalidsalama/anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# 1.4.1

# %%
MODEL_NAME = 'cenus-model-01'

TRAIN_DATA_FILES_PATTERN = 'data/adult.data.csv'
TEST_DATA_FILES_PATTERN = 'data/adult.test.csv'

RESUME_TRAINING = False
PROCESS_FEATURES = True
EXTEND_FEATURE_COLUMNS = False
MULTI_THREADING = True

# %% [markdown]
# ## Define Dataset Metadata

# %%
HEADER = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
               'marital_status', 'occupation', 'relationship', 'race', 'gender',
               'capital_gain', 'capital_loss', 'hours_per_week',
               'native_country', 'income_bracket']

HEADER_DEFAULTS = [[0], [''], [0], [''], [0], [''], [''], [''], [''], [''],
                       [0], [0], [0], [''], ['']]

NUMERIC_FEATURE_NAMES = ['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']

CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY = {
    'gender': ['Female', 'Male'],
    
    'race': ['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'],
    
    'education': ['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college', 
                  'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school', 
                  '5th-6th', '10th', '1st-4th', 'Preschool', '12th'],
    
    'marital_status': ['Married-civ-spouse', 'Divorced', 'Married-spouse-absent', 
                       'Never-married', 'Separated', 'Married-AF-spouse', 'Widowed'],
    
    'relationship': ['Husband', 'Not-in-family', 'Wife', 'Own-child', 'Unmarried', 'Other-relative'],
    
    'workclass': ['Self-emp-not-inc', 'Private', 'State-gov', 'Federal-gov', 'Local-gov', '?', 
                  'Self-emp-inc', 'Without-pay', 'Never-worked']
}

CATEGORICAL_FEATURE_NAMES_WITH_BUCKET_SIZE = {
    'occupation': 50,
    'native_country' : 100
}

CATEGORICAL_FEATURE_NAMES = list(CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.keys()) + list(CATEGORICAL_FEATURE_NAMES_WITH_BUCKET_SIZE.keys())

FEATURE_NAMES = NUMERIC_FEATURE_NAMES + CATEGORICAL_FEATURE_NAMES

TARGET_NAME = 'income_bracket'

TARGET_LABELS = ['<=50K', '>50K']

WEIGHT_COLUMN_NAME = 'fnlwgt'

UNUSED_FEATURE_NAMES = list(set(HEADER) - set(FEATURE_NAMES) - {TARGET_NAME})


print("Header: {}".format(HEADER))
print("Numeric Features: {}".format(NUMERIC_FEATURE_NAMES))
print("Categorical Features: {}".format(CATEGORICAL_FEATURE_NAMES))
print("Target: {} - labels: {}".format(TARGET_NAME, TARGET_LABELS))
print("Unused Features: {}".format(UNUSED_FEATURE_NAMES))
# Out:
# Header: ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'gender', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income_bracket']
# Numeric Features: ['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']
# Categorical Features: ['gender', 'race', 'education', 'marital_status', 'relationship', 'workclass', 'occupation', 'native_country']
# Target: income_bracket - labels: ['<=50K', '>50K']
# Unused Features: []

# %% [markdown]
# ## Load and Analyse Dataset

# %%
TRAIN_DATA_SIZE = 32561
TEST_DATA_SIZE = 16278

train_data = pd.read_csv(TRAIN_DATA_FILES_PATTERN, header=None, names=HEADER )
train_data.head(10)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
# 8   31           Private   45781    Masters             14
# 9   42           Private  159449  Bachelors             13
#
#           marital_status         occupation   relationship   race  gender  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4     Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 5     Married-civ-spouse    Exec-managerial           Wife  White  Female
# 6  Married-spouse-absent      Other-service  Not-in-family  Black  Female
# 7     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 8          Never-married     Prof-specialty  Not-in-family  White  Female
# 9     Married-civ-spouse    Exec-managerial        Husband  White    Male
#
#    capital_gain  capital_loss  hours_per_week native_country income_bracket
# 0          2174             0              40  United-States          <=50K
# 1             0             0              13  United-States          <=50K
# 2             0             0              40  United-States          <=50K
# 3             0             0              40  United-States          <=50K
# 4             0             0              40           Cuba          <=50K
# 5             0             0              40  United-States          <=50K
# 6             0             0              16        Jamaica          <=50K
# 7             0             0              45  United-States           >50K
# 8         14084             0              50  United-States           >50K
# 9          5178             0              40  United-States           >50K

# %%
train_data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### Compute Scaling Statistics for Numeric Columns

# %%
means = train_data[NUMERIC_FEATURE_NAMES].mean(axis=0)
stdvs = train_data[NUMERIC_FEATURE_NAMES].std(axis=0)
maxs = train_data[NUMERIC_FEATURE_NAMES].max(axis=0)
mins = train_data[NUMERIC_FEATURE_NAMES].min(axis=0)
df_stats = pd.DataFrame({"mean":means, "stdv":stdvs, "max":maxs, "min":mins})
df_stats.head(15)
# Out:
#                     max           mean    min           stdv
# age                  90      38.581647     17      13.640433
# fnlwgt          1484705  189778.366512  12285  105549.977697
# education_num        16      10.080679      1       2.572720
# capital_gain      99999    1077.648844      0    7385.292085
# capital_loss       4356      87.303830      0     402.960219
# hours_per_week       99      40.437456      1      12.347429

# %% [markdown]
# ### Save Scaling Statistics

# %%
df_stats.to_csv(path_or_buf="data/adult.stats.csv", header=True, index=True)

# %% [markdown]
# ## Define Data Input Function

# %% [markdown]
# ### a. Parsing and preprocessing logic

# %%
def parse_csv_row(csv_row):
    
    columns = tf.decode_csv(csv_row, record_defaults=HEADER_DEFAULTS)
    features = dict(zip(HEADER, columns))
    
    for column in UNUSED_FEATURE_NAMES:
        features.pop(column)
    
    target = features.pop(TARGET_NAME)

    return features, target

def process_features(features):

    capital_indicator = features['capital_gain'] > features['capital_loss']
    features['capital_indicator'] = tf.cast(capital_indicator, dtype=tf.int32)
    
    return features

# %% [markdown]
# ### b. Data pipeline input function

# %%
def parse_label_column(label_string_tensor):
    table = tf.contrib.lookup.index_table_from_tensor(tf.constant(TARGET_LABELS))
    return table.lookup(label_string_tensor)

def csv_input_fn(files_name_pattern, mode=tf.estimator.ModeKeys.EVAL, 
                 skip_header_lines=0, 
                 num_epochs=None, 
                 batch_size=200):
    
    shuffle = True if mode == tf.estimator.ModeKeys.TRAIN else False
        
    num_threads = multiprocessing.cpu_count() if MULTI_THREADING else 1
     
    print("")
    print("* data input_fn:")
    print("================")
    print("Input file(s): {}".format(files_name_pattern))
    print("Batch size: {}".format(batch_size))
    print("Epoch Count: {}".format(num_epochs))
    print("Mode: {}".format(mode))
    print("Thread Count: {}".format(num_threads))
    print("Shuffle: {}".format(shuffle))
    print("================")
    print("")

    file_names = tf.matching_files(files_name_pattern)
    dataset = data.TextLineDataset(filenames=file_names)
    
    dataset = dataset.skip(skip_header_lines)
    
    if shuffle:
        dataset = dataset.shuffle(buffer_size=2 * batch_size + 1)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda csv_row: parse_csv_row(csv_row), 
                          num_parallel_calls=num_threads)
    
    if PROCESS_FEATURES:
        dataset = dataset.map(lambda features, target: (process_features(features), target), 
                              num_parallel_calls=num_threads)
        
    dataset = dataset.repeat(num_epochs)
    iterator = dataset.make_one_shot_iterator()
    
    features, target = iterator.get_next()
    return features, parse_label_column(target)

# %%
features, target = csv_input_fn(files_name_pattern="")
print("Features in CSV: {}".format(list(features.keys())))
print("Target in CSV: {}".format(target))
# Out:
# * data input_fn:
# ================
# Input file(s):
# Batch size: 200
# Epoch Count: None
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# Features in CSV: ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'gender', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'capital_indicator']
# Target in CSV: Tensor("hash_table_Lookup:0", shape=(?,), dtype=int64)

# %% [markdown]
# ## Define Feature Columns
# ### a. Load scaling params

# %%
df_stats = pd.read_csv("data/adult.stats.csv", header=0, index_col=0)
df_stats['feature_name'] = NUMERIC_FEATURE_NAMES
df_stats.head(10)
# Out:
#                     max           mean    min           stdv    feature_name
# age                  90      38.581647     17      13.640433             age
# fnlwgt          1484705  189778.366512  12285  105549.977697          fnlwgt
# education_num        16      10.080679      1       2.572720   education_num
# capital_gain      99999    1077.648844      0    7385.292085    capital_gain
# capital_loss       4356      87.303830      0     402.960219    capital_loss
# hours_per_week       99      40.437456      1      12.347429  hours_per_week

# %% [markdown]
# ### b. Create feature columns

# %%
def extend_feature_columns(feature_columns, hparams):
    
    age_buckets = tf.feature_column.bucketized_column(
      feature_columns['age'], boundaries=[18, 25, 30, 35, 40, 45, 50, 55, 60, 65])
    
    education_X_occupation = tf.feature_column.crossed_column(
     [feature_columns['education'], feature_columns['occupation']], hash_bucket_size=int(1e4))
    
    age_buckets_X_race = tf.feature_column.crossed_column(
     [age_buckets, feature_columns['race']], hash_bucket_size=int(1e4))
    
    native_country_X_occupation = tf.feature_column.crossed_column(
          [feature_columns['native_country'], feature_columns['occupation']], hash_bucket_size=int(1e4))
    
    native_country_embedded = tf.feature_column.embedding_column(
          feature_columns['native_country'], dimension=hparams.embedding_size)
    
    occupation_embedded = tf.feature_column.embedding_column(
          feature_columns['occupation'], dimension=hparams.embedding_size)
    
    education_X_occupation_embedded = tf.feature_column.embedding_column(
          education_X_occupation, dimension=hparams.embedding_size)
    
    native_country_X_occupation_embedded = tf.feature_column.embedding_column(
          native_country_X_occupation, dimension=hparams.embedding_size)
    
    
    feature_columns['age_buckets'] = age_buckets
    feature_columns['education_X_occupation'] = education_X_occupation
    feature_columns['age_buckets_X_race'] = age_buckets_X_race
    feature_columns['native_country_X_occupation'] = native_country_X_occupation
    feature_columns['native_country_embedded'] = native_country_embedded
    feature_columns['occupation_embedded'] = native_country_embedded
    feature_columns['education_X_occupation_embedded'] = native_country_embedded
    feature_columns['native_country_X_occupation_embedded'] = native_country_embedded
    
    return feature_columns

def standard_scaler(x, mean, stdv):
    return (x-mean)/(stdv)

def maxmin_scaler(x, max_value, min_value):
    return (x-min_value)/(max_value-min_value)  

def get_feature_columns(hparams):
    
    
    numeric_columns = {}
    
    for feature_name in NUMERIC_FEATURE_NAMES:

        feature_mean = df_stats[df_stats.feature_name == feature_name]['mean'].values[0]
        feature_stdv = df_stats[df_stats.feature_name == feature_name]['stdv'].values[0]
        normalizer_fn = lambda x: standard_scaler(x, feature_mean, feature_stdv)
        
        numeric_columns[feature_name] = tf.feature_column.numeric_column(feature_name, 
                                                                         normalizer_fn=normalizer_fn
                                                                        )
    CONSTRUCTED_NUMERIC_FEATURES_NAMES = []
    
    if PROCESS_FEATURES:
        for feature_name in CONSTRUCTED_NUMERIC_FEATURES_NAMES:
            numeric_columns[feature_name] = tf.feature_column.numeric_column(feature_name)
    
    categorical_column_with_vocabulary = \
        {item[0]: tf.feature_column.categorical_column_with_vocabulary_list(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.items()}
        
    CONSTRUCTED_INDICATOR_FEATURES_NAMES = ['capital_indicator']
    
    categorical_column_with_identity = {}
    
    for feature_name in CONSTRUCTED_INDICATOR_FEATURES_NAMES: 
        categorical_column_with_identity[feature_name] = tf.feature_column.categorical_column_with_identity(feature_name, 
                                                                                                              num_buckets=2,
                                                                                                              default_value=0)
    categorical_column_with_hash_bucket = \
        {item[0]: tf.feature_column.categorical_column_with_hash_bucket(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_BUCKET_SIZE.items()}
        
    feature_columns = {}

    if numeric_columns is not None:
        feature_columns.update(numeric_columns)

    if categorical_column_with_vocabulary is not None:
        feature_columns.update(categorical_column_with_vocabulary)
        
    if categorical_column_with_identity is not None:
        feature_columns.update(categorical_column_with_identity)
        
    if categorical_column_with_hash_bucket is not None:
        feature_columns.update(categorical_column_with_hash_bucket)
    
    if EXTEND_FEATURE_COLUMNS:
        feature_columns = extend_feature_columns(feature_columns, hparams)
        
    return feature_columns

feature_columns = get_feature_columns(tf.contrib.training.HParams(num_buckets=5,embedding_size=3))
print("Feature Columns: {}".format(feature_columns))
# Out:
# Feature Columns: {'age': _NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x120484488>), 'fnlwgt': _NumericColumn(key='fnlwgt', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x120484400>), 'education_num': _NumericColumn(key='education_num', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x120484510>), 'capital_gain': _NumericColumn(key='capital_gain', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x1204841e0>), 'capital_loss': _NumericColumn(key='capital_loss', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x120484598>), 'hours_per_week': _NumericColumn(key='hours_per_week', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x120484620>), 'gender': _VocabularyListCategoricalColumn(key='gender', vocabulary_list=('Female', 'Male'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'race': _VocabularyListCategoricalColumn(key='race', vocabulary_list=('Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'education': _VocabularyListCategoricalColumn(key='education', vocabulary_list=('Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college', 'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school', '5th-6th', '10th', '1st-4th', 'Preschool', '12th'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'marital_status': _VocabularyListCategoricalColumn(key='marital_status', vocabulary_list=('Married-civ-spouse', 'Divorced', 'Married-spouse-absent', 'Never-married', 'Separated', 'Married-AF-spouse', 'Widowed'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'relationship': _VocabularyListCategoricalColumn(key='relationship', vocabulary_list=('Husband', 'Not-in-family', 'Wife', 'Own-child', 'Unmarried', 'Other-relative'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'workclass': _VocabularyListCategoricalColumn(key='workclass', vocabulary_list=('Self-emp-not-inc', 'Private', 'State-gov', 'Federal-gov', 'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'capital_indicator': _IdentityCategoricalColumn(key='capital_indicator', num_buckets=2, default_value=0), 'occupation': _HashedCategoricalColumn(key='occupation', hash_bucket_size=50, dtype=tf.string), 'native_country': _HashedCategoricalColumn(key='native_country', hash_bucket_size=100, dtype=tf.string)}

# %% [markdown]
# ## Define a DNN  Estimator Creation Function

# %% [markdown]
# ### a. Get wide and deep feature columns

# %%
def get_wide_deep_columns():
    
    feature_columns = list(get_feature_columns(hparams).values())
    
    dense_columns = list(
        filter(lambda column: isinstance(column, feature_column._NumericColumn) |
                              isinstance(column, feature_column._EmbeddingColumn),
               feature_columns
        )
    )

    categorical_columns = list(
        filter(lambda column: isinstance(column, feature_column._VocabularyListCategoricalColumn) |
                              isinstance(column, feature_column._IdentityCategoricalColumn) |
                              isinstance(column, feature_column._BucketizedColumn),
                   feature_columns)
    )
    
    sparse_columns = list(
        filter(lambda column: isinstance(column,feature_column._HashedCategoricalColumn) |
                              isinstance(column, feature_column._CrossedColumn),
               feature_columns)
    )

    indicator_columns = list(
            map(lambda column: tf.feature_column.indicator_column(column),
                categorical_columns)
    )
    
    deep_feature_columns = dense_columns + indicator_columns
    wide_feature_columns = categorical_columns + sparse_columns
    
    return wide_feature_columns, deep_feature_columns

# %% [markdown]
# ### b. Define the estimator

# %%
def create_DNNComb_estimator(run_config, hparams, print_desc=False):
    
    wide_feature_columns, deep_feature_columns = get_wide_deep_columns()
    
    estimator = tf.estimator.DNNLinearCombinedClassifier(
        
        n_classes=len(TARGET_LABELS),
        
        dnn_feature_columns = deep_feature_columns,
        linear_feature_columns = wide_feature_columns,
        
        weight_column=WEIGHT_COLUMN_NAME,
        
        dnn_hidden_units= hparams.hidden_units,
        
        dnn_optimizer= tf.train.AdamOptimizer(),
        
        dnn_activation_fn= tf.nn.relu,
        
        config= run_config
    )
    
    
    if print_desc:
        print("")
        print("*Estimator Type:")
        print("================")
        print(type(estimator))
        print("")
        print("*deep columns:")
        print("==============")
        print(deep_feature_columns)
        print("")
        print("wide columns:")
        print("=============")
        print(wide_feature_columns)
        print("")
    
    return estimator

# %% [markdown]
# ## 6. Run Experiment

# %% [markdown]
# ### a. Set HParam and RunConfig

# %%
TRAIN_SIZE = TRAIN_DATA_SIZE
NUM_EPOCHS = 1000
BATCH_SIZE = 500
EVAL_AFTER_SEC = 60
TOTAL_STEPS = (TRAIN_SIZE/BATCH_SIZE)*NUM_EPOCHS

hparams  = tf.contrib.training.HParams(
    num_epochs = NUM_EPOCHS,
    batch_size = BATCH_SIZE,
    hidden_units= [64, 32, 16],
    max_steps = TOTAL_STEPS
)

model_dir = 'trained_models/{}'.format(MODEL_NAME)

run_config = tf.estimator.RunConfig(
    log_step_count_steps=5000,
    tf_random_seed=19830610,
    model_dir=model_dir
)

print(hparams)
print("Model Directory:", run_config.model_dir)
print("")
print("Dataset Size:", TRAIN_SIZE)
print("Batch Size:", BATCH_SIZE)
print("Steps per Epoch:",TRAIN_SIZE/BATCH_SIZE)
print("Total Steps:", TOTAL_STEPS)
print("That is 1 evaluation step after each",EVAL_AFTER_SEC," training seconds")
# Out:
# [('batch_size', 500), ('hidden_units', [64, 32, 16]), ('max_steps', 65122.0), ('num_epochs', 1000)]
# Model Directory: trained_models/cenus-model-01
#
# Dataset Size: 32561
# Batch Size: 500
# Steps per Epoch: 65.122
# Total Steps: 65122.0
# That is 1 evaluation step after each 60  training seconds

# %% [markdown]
# ### b. Define TrainSpec and EvaluSpec

# %%
train_spec = tf.estimator.TrainSpec(
    input_fn = lambda: csv_input_fn(
        TRAIN_DATA_FILES_PATTERN,
        mode = tf.estimator.ModeKeys.TRAIN,
        num_epochs=hparams.num_epochs,
        batch_size=hparams.batch_size
    ),
    max_steps=hparams.max_steps,
    hooks=None
)

eval_spec = tf.estimator.EvalSpec(
    input_fn = lambda: csv_input_fn(
        TRAIN_DATA_FILES_PATTERN,
        mode=tf.estimator.ModeKeys.EVAL,
        num_epochs=1,
        batch_size=hparams.batch_size,
            
    ),
    throttle_secs = EVAL_AFTER_SEC,
    steps=None
)

# %% [markdown]
# ### c. Run Experiment via train_and_evaluate

# %%
if not RESUME_TRAINING:
    print("Removing previous artifacts...")
    shutil.rmtree(model_dir, ignore_errors=True)
else:
    print("Resuming training...") 

    
tf.logging.set_verbosity(tf.logging.INFO)

time_start = datetime.utcnow() 
print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
print(".......................................") 

estimator = create_DNNComb_estimator(run_config, hparams, True)

tf.estimator.train_and_evaluate(
    estimator=estimator,
    train_spec=train_spec, 
    eval_spec=eval_spec
)

time_end = datetime.utcnow() 
print(".......................................")
print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
print("")
time_elapsed = time_end - time_start
print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
# Out:
# Removing previous artifacts...
# Experiment started at 17:23:36
# .......................................
# INFO:tensorflow:Using config: {'_model_dir': 'trained_models/cenus-model-01', '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 5000, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1204cd6d8>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# *Estimator Type:
# ================
# <class 'tensorflow.python.estimator.canned.dnn_linear_combined.DNNLinearCombinedClassifier'>
#
# *deep columns:
# ==============
# [_NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x120484a60>), _NumericColumn(key='fnlwgt', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x1204846a8>), _NumericColumn(key='education_num', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x120484ea0>), _NumericColumn(key='capital_gain', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x1204b7048>), _NumericColumn(key='capital_loss', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x1204b79d8>), _NumericColumn(key='hours_per_week', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function get_feature_columns.<locals>.<lambda> at 0x1204b70d0>), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='gender', vocabulary_list=('Female', 'Male'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='race', vocabulary_list=('Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='education', vocabulary_list=('Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college', 'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school', '5th-6th', '10th', '1st-4th', 'Preschool', '12th'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='marital_status', vocabulary_list=('Married-civ-spouse', 'Divorced', 'Married-spouse-absent', 'Never-married', 'Separated', 'Married-AF-spouse', 'Widowed'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='relationship', vocabulary_list=('Husband', 'Not-in-family', 'Wife', 'Own-child', 'Unmarried', 'Other-relative'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='workclass', vocabulary_list=('Self-emp-not-inc', 'Private', 'State-gov', 'Federal-gov', 'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_IdentityCategoricalColumn(key='capital_indicator', num_buckets=2, default_value=0))]
#
# wide columns:
# =============
# [_VocabularyListCategoricalColumn(key='gender', vocabulary_list=('Female', 'Male'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='race', vocabulary_list=('Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='education', vocabulary_list=('Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college', 'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school', '5th-6th', '10th', '1st-4th', 'Preschool', '12th'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='marital_status', vocabulary_list=('Married-civ-spouse', 'Divorced', 'Married-spouse-absent', 'Never-married', 'Separated', 'Married-AF-spouse', 'Widowed'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='relationship', vocabulary_list=('Husband', 'Not-in-family', 'Wife', 'Own-child', 'Unmarried', 'Other-relative'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='workclass', vocabulary_list=('Self-emp-not-inc', 'Private', 'State-gov', 'Federal-gov', 'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _IdentityCategoricalColumn(key='capital_indicator', num_buckets=2, default_value=0), _HashedCategoricalColumn(key='occupation', hash_bucket_size=50, dtype=tf.string), _HashedCategoricalColumn(key='native_country', hash_bucket_size=100, dtype=tf.string)]
#
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 60 secs (eval_spec.throttle_secs) or training is finished.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 8.16505e+09, step = 1
# INFO:tensorflow:loss = 3.50888e+09, step = 101 (0.862 sec)
# INFO:tensorflow:loss = 6.87083e+08, step = 201 (0.483 sec)
# INFO:tensorflow:loss = 2.9637e+08, step = 301 (0.484 sec)
# INFO:tensorflow:loss = 7.00309e+08, step = 401 (0.482 sec)
# INFO:tensorflow:loss = 3.37616e+08, step = 501 (0.498 sec)
# INFO:tensorflow:loss = 3.44383e+09, step = 601 (0.493 sec)
# INFO:tensorflow:loss = 6.41689e+08, step = 701 (0.493 sec)
# INFO:tensorflow:loss = 4.29782e+08, step = 801 (0.491 sec)
# INFO:tensorflow:loss = 4.71268e+08, step = 901 (0.476 sec)
# INFO:tensorflow:loss = 5.32536e+08, step = 1001 (0.489 sec)
# INFO:tensorflow:loss = 2.59766e+08, step = 1101 (0.480 sec)
# INFO:tensorflow:loss = 3.44702e+08, step = 1201 (0.495 sec)
# INFO:tensorflow:loss = 3.71613e+08, step = 1301 (0.551 sec)
# INFO:tensorflow:loss = 5.66525e+08, step = 1401 (0.534 sec)
# INFO:tensorflow:loss = 1.06125e+08, step = 1501 (0.496 sec)
# INFO:tensorflow:loss = 8.95919e+07, step = 1601 (0.486 sec)
# INFO:tensorflow:loss = 6.12715e+07, step = 1701 (0.495 sec)
# INFO:tensorflow:loss = 2.40158e+08, step = 1801 (0.488 sec)
# INFO:tensorflow:loss = 2.18773e+09, step = 1901 (0.492 sec)
# INFO:tensorflow:loss = 1.81307e+09, step = 2001 (0.494 sec)
# INFO:tensorflow:loss = 3.57662e+08, step = 2101 (0.487 sec)
# INFO:tensorflow:loss = 1.79615e+08, step = 2201 (0.487 sec)
# INFO:tensorflow:loss = 2.81371e+08, step = 2301 (0.483 sec)
# INFO:tensorflow:loss = 8.22176e+08, step = 2401 (0.496 sec)
# INFO:tensorflow:loss = 2.70669e+08, step = 2501 (0.482 sec)
# INFO:tensorflow:loss = 2.45735e+08, step = 2601 (0.488 sec)
# INFO:tensorflow:loss = 9.35458e+07, step = 2701 (0.508 sec)
# INFO:tensorflow:loss = 7.12494e+08, step = 2801 (0.502 sec)
# INFO:tensorflow:loss = 1.98119e+08, step = 2901 (0.488 sec)
# INFO:tensorflow:loss = 8.42597e+07, step = 3001 (0.494 sec)
# INFO:tensorflow:loss = 2.60141e+08, step = 3101 (0.477 sec)
# INFO:tensorflow:loss = 5.06908e+08, step = 3201 (0.496 sec)
# INFO:tensorflow:loss = 7.49223e+07, step = 3301 (0.475 sec)
# INFO:tensorflow:loss = 8.74973e+07, step = 3401 (0.490 sec)
# INFO:tensorflow:loss = 6.29281e+07, step = 3501 (0.484 sec)
# INFO:tensorflow:loss = 6.82702e+07, step = 3601 (0.487 sec)
# INFO:tensorflow:loss = 6.45983e+07, step = 3701 (0.478 sec)
# INFO:tensorflow:loss = 5.15475e+07, step = 3801 (0.484 sec)
# INFO:tensorflow:loss = 2.99124e+08, step = 3901 (0.481 sec)
# INFO:tensorflow:loss = 1.89228e+08, step = 4001 (0.482 sec)
# INFO:tensorflow:loss = 6.75847e+07, step = 4101 (0.481 sec)
# INFO:tensorflow:loss = 4.93686e+08, step = 4201 (0.481 sec)
# INFO:tensorflow:loss = 2.23359e+08, step = 4301 (0.480 sec)
# INFO:tensorflow:loss = 9.43984e+07, step = 4401 (0.483 sec)
# INFO:tensorflow:loss = 9.96166e+07, step = 4501 (0.480 sec)
# INFO:tensorflow:loss = 9.90563e+07, step = 4601 (0.488 sec)
# INFO:tensorflow:loss = 2.55304e+08, step = 4701 (0.477 sec)
# INFO:tensorflow:loss = 4.51222e+08, step = 4801 (0.478 sec)
# INFO:tensorflow:loss = 2.24459e+08, step = 4901 (0.479 sec)
# INFO:tensorflow:global_step/sec: 201.409
# INFO:tensorflow:loss = 4.68138e+07, step = 5001 (0.490 sec)
# INFO:tensorflow:loss = 7.26102e+07, step = 5101 (0.481 sec)
# INFO:tensorflow:loss = 7.37385e+07, step = 5201 (0.491 sec)
# INFO:tensorflow:loss = 5.57573e+08, step = 5301 (0.480 sec)
# INFO:tensorflow:loss = 2.20042e+08, step = 5401 (0.486 sec)
# INFO:tensorflow:loss = 5.75594e+07, step = 5501 (0.512 sec)
# INFO:tensorflow:loss = 6.9385e+07, step = 5601 (0.555 sec)
# INFO:tensorflow:loss = 5.69733e+07, step = 5701 (0.528 sec)
# INFO:tensorflow:loss = 6.42567e+07, step = 5801 (0.472 sec)
# INFO:tensorflow:loss = 7.52395e+07, step = 5901 (0.588 sec)
# INFO:tensorflow:loss = 1.92751e+08, step = 6001 (0.593 sec)
# INFO:tensorflow:loss = 1.21588e+08, step = 6101 (0.524 sec)
# INFO:tensorflow:loss = 4.01331e+07, step = 6201 (0.460 sec)
# INFO:tensorflow:loss = 1.09142e+08, step = 6301 (0.465 sec)
# INFO:tensorflow:loss = 4.17464e+07, step = 6401 (0.444 sec)
# INFO:tensorflow:loss = 5.00063e+07, step = 6501 (0.462 sec)
# INFO:tensorflow:loss = 1.51949e+08, step = 6601 (0.455 sec)
# INFO:tensorflow:loss = 2.74032e+08, step = 6701 (0.453 sec)
# INFO:tensorflow:loss = 1.39438e+08, step = 6801 (0.451 sec)
# INFO:tensorflow:loss = 4.18575e+08, step = 6901 (0.456 sec)
# INFO:tensorflow:loss = 3.5019e+08, step = 7001 (0.469 sec)
# INFO:tensorflow:loss = 3.78289e+07, step = 7101 (0.470 sec)
# INFO:tensorflow:loss = 1.85176e+08, step = 7201 (0.458 sec)
# INFO:tensorflow:loss = 1.314e+08, step = 7301 (0.455 sec)
# INFO:tensorflow:loss = 4.66096e+07, step = 7401 (0.475 sec)
# INFO:tensorflow:loss = 7.81954e+07, step = 7501 (0.459 sec)
# INFO:tensorflow:loss = 2.24609e+08, step = 7601 (0.452 sec)
# INFO:tensorflow:loss = 3.64136e+07, step = 7701 (0.460 sec)
# INFO:tensorflow:loss = 3.537e+07, step = 7801 (0.451 sec)
# INFO:tensorflow:loss = 5.50019e+07, step = 7901 (0.457 sec)
# INFO:tensorflow:loss = 3.6718e+07, step = 8001 (0.459 sec)
# INFO:tensorflow:loss = 4.48374e+07, step = 8101 (0.482 sec)
# INFO:tensorflow:loss = 3.80975e+07, step = 8201 (0.484 sec)
# INFO:tensorflow:loss = 3.83763e+07, step = 8301 (0.518 sec)
# INFO:tensorflow:loss = 5.06185e+07, step = 8401 (0.490 sec)
# INFO:tensorflow:loss = 8.34753e+07, step = 8501 (0.467 sec)
# INFO:tensorflow:loss = 1.30676e+08, step = 8601 (0.492 sec)
# INFO:tensorflow:loss = 4.17605e+07, step = 8701 (0.493 sec)
# INFO:tensorflow:loss = 4.67049e+07, step = 8801 (0.464 sec)
# INFO:tensorflow:loss = 2.83248e+07, step = 8901 (0.476 sec)
# INFO:tensorflow:loss = 7.48263e+07, step = 9001 (0.481 sec)
# INFO:tensorflow:loss = 4.43181e+07, step = 9101 (0.464 sec)
# INFO:tensorflow:loss = 3.10031e+07, step = 9201 (0.482 sec)
# INFO:tensorflow:loss = 2.41234e+08, step = 9301 (0.471 sec)
# INFO:tensorflow:loss = 3.51204e+07, step = 9401 (0.476 sec)
# INFO:tensorflow:loss = 3.72025e+07, step = 9501 (0.451 sec)
# INFO:tensorflow:loss = 4.7937e+07, step = 9601 (0.461 sec)
# INFO:tensorflow:loss = 4.07254e+07, step = 9701 (0.450 sec)
# INFO:tensorflow:loss = 3.42363e+07, step = 9801 (0.477 sec)
# INFO:tensorflow:loss = 3.7283e+07, step = 9901 (0.459 sec)
# INFO:tensorflow:global_step/sec: 208.878
# INFO:tensorflow:loss = 3.49749e+07, step = 10001 (0.478 sec)
# INFO:tensorflow:loss = 7.69655e+07, step = 10101 (0.471 sec)
# INFO:tensorflow:loss = 4.01856e+07, step = 10201 (0.490 sec)
# INFO:tensorflow:loss = 4.08556e+07, step = 10301 (0.506 sec)
# INFO:tensorflow:loss = 4.59306e+07, step = 10401 (0.545 sec)
# INFO:tensorflow:loss = 4.91429e+07, step = 10501 (0.564 sec)
# INFO:tensorflow:Saving checkpoints for 10552 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.25725e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-17:24:48
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-10552
# INFO:tensorflow:Finished evaluation at 2017-12-18-17:24:51
# INFO:tensorflow:Saving dict for global step 10552: accuracy = 0.853396, accuracy_baseline = 0.761441, auc = 0.909319, auc_precision_recall = 0.770864, average_loss = 0.317415, global_step = 10552, label/mean = 0.238559, loss = 2.97186e+07, prediction/mean = 0.246209
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-10552
# INFO:tensorflow:Saving checkpoints for 10553 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.18648e+07, step = 10553
# INFO:tensorflow:loss = 3.50031e+07, step = 10653 (0.863 sec)
# INFO:tensorflow:loss = 5.83812e+07, step = 10753 (0.500 sec)
# INFO:tensorflow:loss = 3.34393e+07, step = 10853 (0.507 sec)
# INFO:tensorflow:loss = 2.95257e+07, step = 10953 (0.513 sec)
# INFO:tensorflow:loss = 3.73984e+07, step = 11053 (0.541 sec)
# INFO:tensorflow:loss = 3.11024e+07, step = 11153 (0.529 sec)
# INFO:tensorflow:loss = 1.66608e+08, step = 11253 (0.515 sec)
# INFO:tensorflow:loss = 2.89853e+07, step = 11353 (0.564 sec)
# INFO:tensorflow:loss = 2.97428e+07, step = 11453 (0.574 sec)
# INFO:tensorflow:loss = 2.94754e+07, step = 11553 (0.612 sec)
# INFO:tensorflow:loss = 3.69511e+07, step = 11653 (0.604 sec)
# INFO:tensorflow:loss = 3.78867e+07, step = 11753 (0.807 sec)
# INFO:tensorflow:loss = 1.19953e+08, step = 11853 (0.626 sec)
# INFO:tensorflow:loss = 4.47703e+07, step = 11953 (0.599 sec)
# INFO:tensorflow:loss = 2.84194e+07, step = 12053 (0.706 sec)
# INFO:tensorflow:loss = 3.06049e+07, step = 12153 (0.759 sec)
# INFO:tensorflow:loss = 3.85467e+07, step = 12253 (0.761 sec)
# INFO:tensorflow:loss = 4.02006e+07, step = 12353 (0.487 sec)
# INFO:tensorflow:loss = 3.10275e+07, step = 12453 (0.495 sec)
# INFO:tensorflow:loss = 3.54888e+07, step = 12553 (0.496 sec)
# INFO:tensorflow:loss = 5.33827e+07, step = 12653 (0.795 sec)
# INFO:tensorflow:loss = 3.28055e+07, step = 12753 (0.507 sec)
# INFO:tensorflow:loss = 3.45881e+07, step = 12853 (0.490 sec)
# INFO:tensorflow:loss = 5.04904e+07, step = 12953 (0.487 sec)
# INFO:tensorflow:loss = 3.09563e+07, step = 13053 (0.477 sec)
# INFO:tensorflow:loss = 3.10572e+07, step = 13153 (0.504 sec)
# INFO:tensorflow:loss = 2.8218e+07, step = 13253 (0.497 sec)
# INFO:tensorflow:loss = 3.60901e+07, step = 13353 (0.514 sec)
# INFO:tensorflow:loss = 3.23539e+07, step = 13453 (0.519 sec)
# INFO:tensorflow:loss = 3.29313e+07, step = 13553 (0.531 sec)
# INFO:tensorflow:loss = 3.24813e+07, step = 13653 (0.450 sec)
# INFO:tensorflow:loss = 3.07618e+07, step = 13753 (0.481 sec)
# INFO:tensorflow:loss = 6.05725e+07, step = 13853 (0.472 sec)
# INFO:tensorflow:loss = 3.79073e+07, step = 13953 (0.463 sec)
# INFO:tensorflow:loss = 3.40408e+07, step = 14053 (0.454 sec)
# INFO:tensorflow:loss = 2.98008e+07, step = 14153 (0.459 sec)
# INFO:tensorflow:loss = 3.54315e+07, step = 14253 (0.460 sec)
# INFO:tensorflow:loss = 3.04785e+07, step = 14353 (0.490 sec)
# INFO:tensorflow:loss = 3.10906e+07, step = 14453 (0.464 sec)
# INFO:tensorflow:loss = 3.09479e+07, step = 14553 (0.471 sec)
# INFO:tensorflow:loss = 2.76105e+07, step = 14653 (0.457 sec)
# INFO:tensorflow:loss = 3.21614e+07, step = 14753 (0.458 sec)
# INFO:tensorflow:loss = 3.51704e+07, step = 14853 (0.459 sec)
# INFO:tensorflow:loss = 9.8415e+07, step = 14953 (0.479 sec)
# INFO:tensorflow:loss = 3.17112e+07, step = 15053 (0.466 sec)
# INFO:tensorflow:loss = 3.5521e+07, step = 15153 (0.471 sec)
# INFO:tensorflow:loss = 3.09854e+07, step = 15253 (0.488 sec)
# INFO:tensorflow:loss = 3.50606e+07, step = 15353 (0.512 sec)
# INFO:tensorflow:loss = 3.04725e+07, step = 15453 (0.486 sec)
# INFO:tensorflow:global_step/sec: 186.406
# INFO:tensorflow:loss = 3.04606e+07, step = 15553 (0.508 sec)
# INFO:tensorflow:loss = 2.93022e+07, step = 15653 (0.554 sec)
# INFO:tensorflow:loss = 3.06893e+07, step = 15753 (0.502 sec)
# INFO:tensorflow:loss = 3.36291e+07, step = 15853 (0.604 sec)
# INFO:tensorflow:loss = 2.89236e+07, step = 15953 (0.532 sec)
# INFO:tensorflow:loss = 3.68923e+07, step = 16053 (0.571 sec)
# INFO:tensorflow:loss = 3.63512e+07, step = 16153 (0.625 sec)
# INFO:tensorflow:loss = 3.4445e+07, step = 16253 (0.517 sec)
# INFO:tensorflow:loss = 3.52723e+07, step = 16353 (0.566 sec)
# INFO:tensorflow:loss = 2.66035e+07, step = 16453 (0.526 sec)
# INFO:tensorflow:loss = 3.24157e+07, step = 16553 (0.575 sec)
# INFO:tensorflow:loss = 3.45085e+07, step = 16653 (0.514 sec)
# INFO:tensorflow:loss = 3.05018e+07, step = 16753 (0.536 sec)
# INFO:tensorflow:loss = 3.12004e+07, step = 16853 (0.506 sec)
# INFO:tensorflow:loss = 3.71518e+07, step = 16953 (0.483 sec)
# INFO:tensorflow:loss = 3.25447e+07, step = 17053 (0.547 sec)
# INFO:tensorflow:loss = 3.73089e+07, step = 17153 (0.775 sec)
# INFO:tensorflow:loss = 3.19057e+07, step = 17253 (0.745 sec)
# INFO:tensorflow:loss = 3.32628e+07, step = 17353 (0.586 sec)
# INFO:tensorflow:loss = 2.97498e+07, step = 17453 (0.695 sec)
# INFO:tensorflow:loss = 3.05016e+07, step = 17553 (0.572 sec)
# INFO:tensorflow:loss = 2.98281e+07, step = 17653 (0.754 sec)
# INFO:tensorflow:loss = 3.2281e+07, step = 17753 (0.605 sec)
# INFO:tensorflow:loss = 3.22648e+07, step = 17853 (0.555 sec)
# INFO:tensorflow:loss = 3.1875e+07, step = 17953 (0.633 sec)
# INFO:tensorflow:loss = 3.19588e+07, step = 18053 (0.600 sec)
# INFO:tensorflow:loss = 3.59366e+07, step = 18153 (0.617 sec)
# INFO:tensorflow:loss = 2.96031e+07, step = 18253 (0.725 sec)
# INFO:tensorflow:loss = 2.97009e+07, step = 18353 (0.645 sec)
# INFO:tensorflow:loss = 3.18543e+07, step = 18453 (0.603 sec)
# INFO:tensorflow:loss = 3.05664e+07, step = 18553 (0.544 sec)
# INFO:tensorflow:loss = 3.11068e+07, step = 18653 (0.536 sec)
# INFO:tensorflow:loss = 3.08214e+07, step = 18753 (0.588 sec)
# INFO:tensorflow:loss = 2.948e+07, step = 18853 (0.566 sec)
# INFO:tensorflow:loss = 3.2494e+07, step = 18953 (0.728 sec)
# INFO:tensorflow:loss = 3.76648e+07, step = 19053 (0.557 sec)
# INFO:tensorflow:loss = 3.28761e+07, step = 19153 (0.503 sec)
# INFO:tensorflow:loss = 3.78086e+07, step = 19253 (0.466 sec)
# INFO:tensorflow:loss = 3.55695e+07, step = 19353 (0.602 sec)
# INFO:tensorflow:loss = 2.87797e+07, step = 19453 (0.523 sec)
# INFO:tensorflow:loss = 2.88972e+07, step = 19553 (0.523 sec)
# INFO:tensorflow:Saving checkpoints for 19616 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.46492e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-17:26:02
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-19616
# INFO:tensorflow:Finished evaluation at 2017-12-18-17:26:05
# INFO:tensorflow:Saving dict for global step 19616: accuracy = 0.846791, accuracy_baseline = 0.761441, auc = 0.908192, auc_precision_recall = 0.77156, average_loss = 0.325684, global_step = 19616, label/mean = 0.238559, loss = 3.04928e+07, prediction/mean = 0.211652
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-19616
# INFO:tensorflow:Saving checkpoints for 19617 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.37385e+07, step = 19617
# INFO:tensorflow:loss = 3.87764e+07, step = 19717 (0.905 sec)
# INFO:tensorflow:loss = 3.26858e+07, step = 19817 (0.521 sec)
# INFO:tensorflow:loss = 2.95038e+07, step = 19917 (0.474 sec)
# INFO:tensorflow:loss = 3.04402e+07, step = 20017 (0.538 sec)
# INFO:tensorflow:loss = 2.72023e+07, step = 20117 (0.509 sec)
# INFO:tensorflow:loss = 3.34729e+07, step = 20217 (0.523 sec)
# INFO:tensorflow:loss = 4.20194e+07, step = 20317 (0.502 sec)
# INFO:tensorflow:loss = 3.44079e+07, step = 20417 (0.451 sec)
# INFO:tensorflow:loss = 3.15315e+07, step = 20517 (0.458 sec)
# INFO:tensorflow:loss = 3.34265e+07, step = 20617 (0.476 sec)
# INFO:tensorflow:loss = 3.21077e+07, step = 20717 (0.500 sec)
# INFO:tensorflow:loss = 3.61377e+07, step = 20817 (0.482 sec)
# INFO:tensorflow:loss = 4.39243e+07, step = 20917 (0.472 sec)
# INFO:tensorflow:loss = 3.2024e+07, step = 21017 (0.483 sec)
# INFO:tensorflow:loss = 2.85761e+07, step = 21117 (0.488 sec)
# INFO:tensorflow:loss = 3.01682e+07, step = 21217 (0.457 sec)
# INFO:tensorflow:loss = 3.40119e+07, step = 21317 (0.502 sec)
# INFO:tensorflow:loss = 3.3061e+07, step = 21417 (0.517 sec)
# INFO:tensorflow:loss = 3.12021e+07, step = 21517 (0.573 sec)
# INFO:tensorflow:loss = 3.77448e+07, step = 21617 (0.498 sec)
# INFO:tensorflow:loss = 2.87905e+07, step = 21717 (0.496 sec)
# INFO:tensorflow:loss = 3.01219e+07, step = 21817 (0.577 sec)
# INFO:tensorflow:loss = 3.40029e+07, step = 21917 (0.532 sec)
# INFO:tensorflow:loss = 4.05048e+07, step = 22017 (0.517 sec)
# INFO:tensorflow:loss = 2.97947e+07, step = 22117 (0.487 sec)
# INFO:tensorflow:loss = 4.39783e+07, step = 22217 (0.537 sec)
# INFO:tensorflow:loss = 2.82892e+07, step = 22317 (0.583 sec)
# INFO:tensorflow:loss = 3.7953e+07, step = 22417 (0.491 sec)
# INFO:tensorflow:loss = 3.30181e+07, step = 22517 (0.858 sec)
# INFO:tensorflow:loss = 3.27803e+07, step = 22617 (0.527 sec)
# INFO:tensorflow:loss = 2.93001e+07, step = 22717 (0.472 sec)
# INFO:tensorflow:loss = 3.25615e+07, step = 22817 (0.474 sec)
# INFO:tensorflow:loss = 3.43266e+07, step = 22917 (0.482 sec)
# INFO:tensorflow:loss = 3.17836e+07, step = 23017 (0.472 sec)
# INFO:tensorflow:loss = 3.12962e+07, step = 23117 (0.497 sec)
# INFO:tensorflow:loss = 3.42501e+07, step = 23217 (0.503 sec)
# INFO:tensorflow:loss = 2.94404e+07, step = 23317 (0.485 sec)
# INFO:tensorflow:loss = 3.04265e+07, step = 23417 (0.525 sec)
# INFO:tensorflow:loss = 3.3039e+07, step = 23517 (0.502 sec)
# INFO:tensorflow:loss = 3.2213e+07, step = 23617 (0.585 sec)
# INFO:tensorflow:loss = 2.72056e+07, step = 23717 (0.542 sec)
# INFO:tensorflow:loss = 3.00368e+07, step = 23817 (0.485 sec)
# INFO:tensorflow:loss = 3.05696e+07, step = 23917 (0.477 sec)
# INFO:tensorflow:loss = 3.42812e+07, step = 24017 (0.480 sec)
# INFO:tensorflow:loss = 2.98876e+07, step = 24117 (0.496 sec)
# INFO:tensorflow:loss = 3.30273e+07, step = 24217 (0.683 sec)
# INFO:tensorflow:loss = 2.80771e+07, step = 24317 (0.537 sec)
# INFO:tensorflow:loss = 3.37657e+07, step = 24417 (0.507 sec)
# INFO:tensorflow:loss = 2.89645e+07, step = 24517 (0.482 sec)
# INFO:tensorflow:global_step/sec: 191.506
# INFO:tensorflow:loss = 2.77908e+07, step = 24617 (0.490 sec)
# INFO:tensorflow:loss = 2.76407e+07, step = 24717 (0.548 sec)
# INFO:tensorflow:loss = 2.76414e+07, step = 24817 (0.552 sec)
# INFO:tensorflow:loss = 3.24552e+07, step = 24917 (0.523 sec)
# INFO:tensorflow:loss = 2.77645e+07, step = 25017 (0.480 sec)
# INFO:tensorflow:loss = 3.30573e+07, step = 25117 (0.655 sec)
# INFO:tensorflow:loss = 3.2507e+07, step = 25217 (0.553 sec)
# INFO:tensorflow:loss = 3.38571e+07, step = 25317 (0.477 sec)
# INFO:tensorflow:loss = 3.47041e+07, step = 25417 (0.461 sec)
# INFO:tensorflow:loss = 2.60874e+07, step = 25517 (0.514 sec)
# INFO:tensorflow:loss = 3.3904e+07, step = 25617 (0.474 sec)
# INFO:tensorflow:loss = 3.44531e+07, step = 25717 (0.495 sec)
# INFO:tensorflow:loss = 2.72792e+07, step = 25817 (0.546 sec)
# INFO:tensorflow:loss = 3.06199e+07, step = 25917 (0.558 sec)
# INFO:tensorflow:loss = 3.88351e+07, step = 26017 (0.535 sec)
# INFO:tensorflow:loss = 3.07709e+07, step = 26117 (0.556 sec)
# INFO:tensorflow:loss = 3.21768e+07, step = 26217 (0.520 sec)
# INFO:tensorflow:loss = 3.20451e+07, step = 26317 (0.535 sec)
# INFO:tensorflow:loss = 3.37175e+07, step = 26417 (0.500 sec)
# INFO:tensorflow:loss = 2.80804e+07, step = 26517 (0.639 sec)
# INFO:tensorflow:loss = 2.85373e+07, step = 26617 (0.649 sec)
# INFO:tensorflow:loss = 3.41196e+07, step = 26717 (0.472 sec)
# INFO:tensorflow:loss = 3.26732e+07, step = 26817 (0.464 sec)
# INFO:tensorflow:loss = 3.29038e+07, step = 26917 (0.481 sec)
# INFO:tensorflow:loss = 3.05536e+07, step = 27017 (0.484 sec)
# INFO:tensorflow:loss = 2.93458e+07, step = 27117 (0.483 sec)
# INFO:tensorflow:loss = 3.48396e+07, step = 27217 (0.478 sec)
# INFO:tensorflow:loss = 2.8774e+07, step = 27317 (0.529 sec)
# INFO:tensorflow:loss = 2.92376e+07, step = 27417 (0.510 sec)
# INFO:tensorflow:loss = 3.05277e+07, step = 27517 (0.468 sec)
# INFO:tensorflow:loss = 2.96397e+07, step = 27617 (0.485 sec)
# INFO:tensorflow:loss = 3.71509e+07, step = 27717 (0.489 sec)
# INFO:tensorflow:loss = 2.87621e+07, step = 27817 (0.473 sec)
# INFO:tensorflow:loss = 3.01571e+07, step = 27917 (0.534 sec)
# INFO:tensorflow:loss = 3.20406e+07, step = 28017 (0.539 sec)
# INFO:tensorflow:loss = 3.56112e+07, step = 28117 (0.494 sec)
# INFO:tensorflow:loss = 3.23787e+07, step = 28217 (0.458 sec)
# INFO:tensorflow:loss = 3.13878e+07, step = 28317 (0.579 sec)
# INFO:tensorflow:loss = 3.66747e+07, step = 28417 (0.573 sec)
# INFO:tensorflow:loss = 2.69956e+07, step = 28517 (0.576 sec)
# INFO:tensorflow:loss = 2.76871e+07, step = 28617 (0.507 sec)
# INFO:tensorflow:loss = 3.31985e+07, step = 28717 (0.494 sec)
# INFO:tensorflow:loss = 2.79454e+07, step = 28817 (0.479 sec)
# INFO:tensorflow:loss = 2.89162e+07, step = 28917 (0.718 sec)
# INFO:tensorflow:loss = 2.93759e+07, step = 29017 (0.547 sec)
# INFO:tensorflow:loss = 3.055e+07, step = 29117 (0.579 sec)
# INFO:tensorflow:Saving checkpoints for 29150 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.14846e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-17:27:13
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-29150
# INFO:tensorflow:Finished evaluation at 2017-12-18-17:27:16
# INFO:tensorflow:Saving dict for global step 29150: accuracy = 0.855384, accuracy_baseline = 0.761441, auc = 0.910899, auc_precision_recall = 0.777306, average_loss = 0.314557, global_step = 29150, label/mean = 0.238559, loss = 2.9451e+07, prediction/mean = 0.237413
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-29150
# INFO:tensorflow:Saving checkpoints for 29151 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.21008e+07, step = 29151
# INFO:tensorflow:loss = 3.95402e+07, step = 29251 (0.993 sec)
# INFO:tensorflow:loss = 3.3943e+07, step = 29351 (0.553 sec)
# INFO:tensorflow:loss = 3.03145e+07, step = 29451 (0.505 sec)
# INFO:tensorflow:loss = 3.98997e+07, step = 29551 (0.564 sec)
# INFO:tensorflow:loss = 2.65982e+07, step = 29651 (0.551 sec)
# INFO:tensorflow:loss = 3.0344e+07, step = 29751 (0.588 sec)
# INFO:tensorflow:loss = 3.08767e+07, step = 29851 (0.689 sec)
# INFO:tensorflow:loss = 2.96138e+07, step = 29951 (0.522 sec)
# INFO:tensorflow:loss = 4.1383e+07, step = 30051 (0.489 sec)
# INFO:tensorflow:loss = 3.06127e+07, step = 30151 (0.520 sec)
# INFO:tensorflow:loss = 2.96671e+07, step = 30251 (0.472 sec)
# INFO:tensorflow:loss = 2.97334e+07, step = 30351 (0.461 sec)
# INFO:tensorflow:loss = 3.20313e+07, step = 30451 (0.460 sec)
# INFO:tensorflow:loss = 2.85589e+07, step = 30551 (0.458 sec)
# INFO:tensorflow:loss = 2.71883e+07, step = 30651 (0.475 sec)
# INFO:tensorflow:loss = 2.8317e+07, step = 30751 (0.491 sec)
# INFO:tensorflow:loss = 3.12374e+07, step = 30851 (0.513 sec)
# INFO:tensorflow:loss = 3.11752e+07, step = 30951 (0.473 sec)
# INFO:tensorflow:loss = 2.93633e+07, step = 31051 (0.465 sec)
# INFO:tensorflow:loss = 3.41605e+07, step = 31151 (0.466 sec)
# INFO:tensorflow:loss = 2.74247e+07, step = 31251 (0.464 sec)
# INFO:tensorflow:loss = 3.12608e+07, step = 31351 (0.464 sec)
# INFO:tensorflow:loss = 3.63185e+07, step = 31451 (0.479 sec)
# INFO:tensorflow:loss = 4.87779e+07, step = 31551 (0.493 sec)
# INFO:tensorflow:loss = 3.21029e+07, step = 31651 (0.492 sec)
# INFO:tensorflow:loss = 3.69151e+07, step = 31751 (0.531 sec)
# INFO:tensorflow:loss = 2.8953e+07, step = 31851 (0.558 sec)
# INFO:tensorflow:loss = 3.2881e+07, step = 31951 (0.503 sec)
# INFO:tensorflow:loss = 3.2576e+07, step = 32051 (0.472 sec)
# INFO:tensorflow:loss = 3.13239e+07, step = 32151 (0.494 sec)
# INFO:tensorflow:loss = 2.86887e+07, step = 32251 (0.667 sec)
# INFO:tensorflow:loss = 3.1513e+07, step = 32351 (0.750 sec)
# INFO:tensorflow:loss = 3.55698e+07, step = 32451 (0.698 sec)
# INFO:tensorflow:loss = 3.22655e+07, step = 32551 (0.605 sec)
# INFO:tensorflow:loss = 3.1124e+07, step = 32651 (0.679 sec)
# INFO:tensorflow:loss = 3.29419e+07, step = 32751 (0.762 sec)
# INFO:tensorflow:loss = 2.82193e+07, step = 32851 (0.702 sec)
# INFO:tensorflow:loss = 2.69045e+07, step = 32951 (0.503 sec)
# INFO:tensorflow:loss = 3.24226e+07, step = 33051 (0.464 sec)
# INFO:tensorflow:loss = 3.00448e+07, step = 33151 (0.556 sec)
# INFO:tensorflow:loss = 2.8591e+07, step = 33251 (0.569 sec)
# INFO:tensorflow:loss = 2.94944e+07, step = 33351 (0.558 sec)
# INFO:tensorflow:loss = 3.4605e+07, step = 33451 (0.538 sec)
# INFO:tensorflow:loss = 3.16838e+07, step = 33551 (0.477 sec)
# INFO:tensorflow:loss = 2.89346e+07, step = 33651 (0.458 sec)
# INFO:tensorflow:loss = 3.24038e+07, step = 33751 (0.535 sec)
# INFO:tensorflow:loss = 2.68697e+07, step = 33851 (0.546 sec)
# INFO:tensorflow:loss = 3.6846e+07, step = 33951 (0.567 sec)
# INFO:tensorflow:loss = 2.76942e+07, step = 34051 (0.496 sec)
# INFO:tensorflow:global_step/sec: 183.419
# INFO:tensorflow:loss = 2.6915e+07, step = 34151 (0.479 sec)
# INFO:tensorflow:loss = 2.59052e+07, step = 34251 (0.553 sec)
# INFO:tensorflow:loss = 2.75928e+07, step = 34351 (0.564 sec)
# INFO:tensorflow:loss = 3.26584e+07, step = 34451 (0.686 sec)
# INFO:tensorflow:loss = 2.60556e+07, step = 34551 (0.544 sec)
# INFO:tensorflow:loss = 3.24725e+07, step = 34651 (0.480 sec)
# INFO:tensorflow:loss = 3.0827e+07, step = 34751 (0.514 sec)
# INFO:tensorflow:loss = 3.41356e+07, step = 34851 (0.565 sec)
# INFO:tensorflow:loss = 3.48745e+07, step = 34951 (0.509 sec)
# INFO:tensorflow:loss = 2.56121e+07, step = 35051 (0.520 sec)
# INFO:tensorflow:loss = 3.62362e+07, step = 35151 (0.475 sec)
# INFO:tensorflow:loss = 3.48036e+07, step = 35251 (0.522 sec)
# INFO:tensorflow:loss = 2.68417e+07, step = 35351 (0.540 sec)
# INFO:tensorflow:loss = 3.10021e+07, step = 35451 (0.474 sec)
# INFO:tensorflow:loss = 3.24131e+07, step = 35551 (0.455 sec)
# INFO:tensorflow:loss = 3.06192e+07, step = 35651 (0.480 sec)
# INFO:tensorflow:loss = 3.03992e+07, step = 35751 (0.492 sec)
# INFO:tensorflow:loss = 3.16356e+07, step = 35851 (0.518 sec)
# INFO:tensorflow:loss = 3.83182e+07, step = 35951 (0.535 sec)
# INFO:tensorflow:loss = 2.76868e+07, step = 36051 (0.604 sec)
# INFO:tensorflow:loss = 2.94785e+07, step = 36151 (0.514 sec)
# INFO:tensorflow:loss = 3.09406e+07, step = 36251 (0.469 sec)
# INFO:tensorflow:loss = 2.96188e+07, step = 36351 (0.462 sec)
# INFO:tensorflow:loss = 3.08357e+07, step = 36451 (0.460 sec)
# INFO:tensorflow:loss = 3.38731e+07, step = 36551 (0.580 sec)
# INFO:tensorflow:loss = 2.9216e+07, step = 36651 (0.685 sec)
# INFO:tensorflow:loss = 3.47897e+07, step = 36751 (0.493 sec)
# INFO:tensorflow:loss = 2.7554e+07, step = 36851 (0.513 sec)
# INFO:tensorflow:loss = 2.82509e+07, step = 36951 (0.514 sec)
# INFO:tensorflow:loss = 3.05896e+07, step = 37051 (0.475 sec)
# INFO:tensorflow:loss = 2.89452e+07, step = 37151 (0.469 sec)
# INFO:tensorflow:loss = 3.13248e+07, step = 37251 (0.463 sec)
# INFO:tensorflow:loss = 3.51327e+07, step = 37351 (0.511 sec)
# INFO:tensorflow:loss = 3.07098e+07, step = 37451 (0.493 sec)
# INFO:tensorflow:loss = 3.08561e+07, step = 37551 (0.482 sec)
# INFO:tensorflow:loss = 3.83828e+07, step = 37651 (0.468 sec)
# INFO:tensorflow:loss = 3.65158e+07, step = 37751 (0.464 sec)
# INFO:tensorflow:loss = 3.75156e+07, step = 37851 (0.593 sec)
# INFO:tensorflow:loss = 3.28032e+07, step = 37951 (0.519 sec)
# INFO:tensorflow:loss = 2.76545e+07, step = 38051 (0.502 sec)
# INFO:tensorflow:loss = 2.81821e+07, step = 38151 (0.475 sec)
# INFO:tensorflow:loss = 3.35704e+07, step = 38251 (0.489 sec)
# INFO:tensorflow:loss = 2.83011e+07, step = 38351 (0.500 sec)
# INFO:tensorflow:Saving checkpoints for 38450 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.71543e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-17:28:23
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-38450
# INFO:tensorflow:Finished evaluation at 2017-12-18-17:28:25
# INFO:tensorflow:Saving dict for global step 38450: accuracy = 0.854222, accuracy_baseline = 0.761441, auc = 0.911637, auc_precision_recall = 0.778562, average_loss = 0.314322, global_step = 38450, label/mean = 0.238559, loss = 2.9429e+07, prediction/mean = 0.229749
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-38450
# INFO:tensorflow:Saving checkpoints for 38451 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.20731e+07, step = 38451
# INFO:tensorflow:loss = 3.18716e+07, step = 38551 (0.889 sec)
# INFO:tensorflow:loss = 3.19638e+07, step = 38651 (0.620 sec)
# INFO:tensorflow:loss = 3.01233e+07, step = 38751 (0.618 sec)
# INFO:tensorflow:loss = 2.82442e+07, step = 38851 (0.711 sec)
# INFO:tensorflow:loss = 2.67791e+07, step = 38951 (0.659 sec)
# INFO:tensorflow:loss = 3.19786e+07, step = 39051 (0.612 sec)
# INFO:tensorflow:loss = 3.05215e+07, step = 39151 (0.587 sec)
# INFO:tensorflow:loss = 3.47198e+07, step = 39251 (0.660 sec)
# INFO:tensorflow:loss = 2.97567e+07, step = 39351 (0.584 sec)
# INFO:tensorflow:loss = 2.93606e+07, step = 39451 (0.592 sec)
# INFO:tensorflow:loss = 3.11719e+07, step = 39551 (0.603 sec)
# INFO:tensorflow:loss = 3.1058e+07, step = 39651 (0.596 sec)
# INFO:tensorflow:loss = 3.08565e+07, step = 39751 (0.604 sec)
# INFO:tensorflow:loss = 2.94429e+07, step = 39851 (0.600 sec)
# INFO:tensorflow:loss = 2.56899e+07, step = 39951 (0.627 sec)
# INFO:tensorflow:loss = 2.82523e+07, step = 40051 (0.599 sec)
# INFO:tensorflow:loss = 2.88879e+07, step = 40151 (0.623 sec)
# INFO:tensorflow:loss = 3.05419e+07, step = 40251 (0.630 sec)
# INFO:tensorflow:loss = 3.52154e+07, step = 40351 (0.595 sec)
# INFO:tensorflow:loss = 3.39693e+07, step = 40451 (0.597 sec)
# INFO:tensorflow:loss = 2.76003e+07, step = 40551 (0.624 sec)
# INFO:tensorflow:loss = 2.76835e+07, step = 40651 (0.637 sec)
# INFO:tensorflow:loss = 3.38086e+07, step = 40751 (0.622 sec)
# INFO:tensorflow:loss = 3.61531e+07, step = 40851 (0.616 sec)
# INFO:tensorflow:loss = 2.84694e+07, step = 40951 (0.602 sec)
# INFO:tensorflow:loss = 3.46447e+07, step = 41051 (0.620 sec)
# INFO:tensorflow:loss = 2.72709e+07, step = 41151 (0.601 sec)
# INFO:tensorflow:loss = 4.89099e+07, step = 41251 (0.630 sec)
# INFO:tensorflow:loss = 3.31998e+07, step = 41351 (0.607 sec)
# INFO:tensorflow:loss = 3.15538e+07, step = 41451 (0.634 sec)
# INFO:tensorflow:loss = 2.76484e+07, step = 41551 (0.479 sec)
# INFO:tensorflow:loss = 3.05452e+07, step = 41651 (0.466 sec)
# INFO:tensorflow:loss = 3.18544e+07, step = 41751 (0.482 sec)
# INFO:tensorflow:loss = 3.16379e+07, step = 41851 (0.470 sec)
# INFO:tensorflow:loss = 3.38363e+07, step = 41951 (0.507 sec)
# INFO:tensorflow:loss = 3.04416e+07, step = 42051 (0.489 sec)
# INFO:tensorflow:loss = 2.9717e+07, step = 42151 (0.537 sec)
# INFO:tensorflow:loss = 2.66659e+07, step = 42251 (0.466 sec)
# INFO:tensorflow:loss = 3.07701e+07, step = 42351 (0.514 sec)
# INFO:tensorflow:loss = 3.23114e+07, step = 42451 (0.484 sec)
# INFO:tensorflow:loss = 2.61368e+07, step = 42551 (0.473 sec)
# INFO:tensorflow:loss = 2.88789e+07, step = 42651 (0.473 sec)
# INFO:tensorflow:loss = 3.43575e+07, step = 42751 (0.459 sec)
# INFO:tensorflow:loss = 3.08381e+07, step = 42851 (0.455 sec)
# INFO:tensorflow:loss = 3.01587e+07, step = 42951 (0.454 sec)
# INFO:tensorflow:loss = 3.19623e+07, step = 43051 (0.463 sec)
# INFO:tensorflow:loss = 2.88207e+07, step = 43151 (0.455 sec)
# INFO:tensorflow:loss = 3.13263e+07, step = 43251 (0.462 sec)
# INFO:tensorflow:loss = 2.86881e+07, step = 43351 (0.457 sec)
# INFO:tensorflow:global_step/sec: 176.616
# INFO:tensorflow:loss = 3.06405e+07, step = 43451 (0.466 sec)
# INFO:tensorflow:loss = 2.87572e+07, step = 43551 (0.460 sec)
# INFO:tensorflow:loss = 2.68799e+07, step = 43651 (0.459 sec)
# INFO:tensorflow:loss = 3.2359e+07, step = 43751 (0.460 sec)
# INFO:tensorflow:loss = 2.60711e+07, step = 43851 (0.460 sec)
# INFO:tensorflow:loss = 3.23078e+07, step = 43951 (0.490 sec)
# INFO:tensorflow:loss = 3.23487e+07, step = 44051 (0.475 sec)
# INFO:tensorflow:loss = 3.41007e+07, step = 44151 (0.452 sec)
# INFO:tensorflow:loss = 3.56389e+07, step = 44251 (0.455 sec)
# INFO:tensorflow:loss = 2.59048e+07, step = 44351 (0.457 sec)
# INFO:tensorflow:loss = 3.18263e+07, step = 44451 (0.455 sec)
# INFO:tensorflow:loss = 3.48314e+07, step = 44551 (0.458 sec)
# INFO:tensorflow:loss = 2.58151e+07, step = 44651 (0.452 sec)
# INFO:tensorflow:loss = 3.14673e+07, step = 44751 (0.465 sec)
# INFO:tensorflow:loss = 3.09733e+07, step = 44851 (0.459 sec)
# INFO:tensorflow:loss = 3.01752e+07, step = 44951 (0.483 sec)
# INFO:tensorflow:loss = 3.03203e+07, step = 45051 (0.524 sec)
# INFO:tensorflow:loss = 3.39566e+07, step = 45151 (0.512 sec)
# INFO:tensorflow:loss = 3.22055e+07, step = 45251 (0.549 sec)
# INFO:tensorflow:loss = 2.79512e+07, step = 45351 (0.500 sec)
# INFO:tensorflow:loss = 2.88258e+07, step = 45451 (0.532 sec)
# INFO:tensorflow:loss = 2.93562e+07, step = 45551 (0.532 sec)
# INFO:tensorflow:loss = 2.94273e+07, step = 45651 (0.458 sec)
# INFO:tensorflow:loss = 3.32802e+07, step = 45751 (0.461 sec)
# INFO:tensorflow:loss = 2.94123e+07, step = 45851 (0.460 sec)
# INFO:tensorflow:loss = 2.86032e+07, step = 45951 (0.460 sec)
# INFO:tensorflow:loss = 3.87135e+07, step = 46051 (0.457 sec)
# INFO:tensorflow:loss = 2.73273e+07, step = 46151 (0.462 sec)
# INFO:tensorflow:loss = 2.79783e+07, step = 46251 (0.459 sec)
# INFO:tensorflow:loss = 3.44535e+07, step = 46351 (0.456 sec)
# INFO:tensorflow:loss = 2.8341e+07, step = 46451 (0.453 sec)
# INFO:tensorflow:loss = 3.38026e+07, step = 46551 (0.468 sec)
# INFO:tensorflow:loss = 3.46562e+07, step = 46651 (0.487 sec)
# INFO:tensorflow:loss = 3.41025e+07, step = 46751 (0.488 sec)
# INFO:tensorflow:loss = 3.21205e+07, step = 46851 (0.495 sec)
# INFO:tensorflow:loss = 3.4431e+07, step = 46951 (0.553 sec)
# INFO:tensorflow:loss = 3.54726e+07, step = 47051 (0.455 sec)
# INFO:tensorflow:loss = 2.99575e+07, step = 47151 (0.499 sec)
# INFO:tensorflow:loss = 3.21963e+07, step = 47251 (0.803 sec)
# INFO:tensorflow:loss = 2.6411e+07, step = 47351 (0.800 sec)
# INFO:tensorflow:loss = 2.81482e+07, step = 47451 (0.523 sec)
# INFO:tensorflow:loss = 3.24211e+07, step = 47551 (0.517 sec)
# INFO:tensorflow:Saving checkpoints for 47638 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.18977e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-17:29:33
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-47638
# INFO:tensorflow:Finished evaluation at 2017-12-18-17:29:35
# INFO:tensorflow:Saving dict for global step 47638: accuracy = 0.838917, accuracy_baseline = 0.761441, auc = 0.902309, auc_precision_recall = 0.764151, average_loss = 0.358777, global_step = 47638, label/mean = 0.238559, loss = 3.35912e+07, prediction/mean = 0.164324
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-47638
# INFO:tensorflow:Saving checkpoints for 47639 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.733e+07, step = 47639
# INFO:tensorflow:loss = 3.18841e+07, step = 47739 (0.882 sec)
# INFO:tensorflow:loss = 3.33765e+07, step = 47839 (0.507 sec)
# INFO:tensorflow:loss = 3.19286e+07, step = 47939 (0.519 sec)
# INFO:tensorflow:loss = 2.83915e+07, step = 48039 (0.506 sec)
# INFO:tensorflow:loss = 2.65958e+07, step = 48139 (0.507 sec)
# INFO:tensorflow:loss = 3.0293e+07, step = 48239 (0.507 sec)
# INFO:tensorflow:loss = 3.02786e+07, step = 48339 (0.513 sec)
# INFO:tensorflow:loss = 3.01829e+07, step = 48439 (0.510 sec)
# INFO:tensorflow:loss = 2.92363e+07, step = 48539 (0.517 sec)
# INFO:tensorflow:loss = 2.92524e+07, step = 48639 (0.522 sec)
# INFO:tensorflow:loss = 3.01255e+07, step = 48739 (0.518 sec)
# INFO:tensorflow:loss = 2.99065e+07, step = 48839 (0.501 sec)
# INFO:tensorflow:loss = 3.24052e+07, step = 48939 (0.534 sec)
# INFO:tensorflow:loss = 3.01605e+07, step = 49039 (0.510 sec)
# INFO:tensorflow:loss = 2.71349e+07, step = 49139 (0.513 sec)
# INFO:tensorflow:loss = 2.8317e+07, step = 49239 (0.514 sec)
# INFO:tensorflow:loss = 2.80737e+07, step = 49339 (0.521 sec)
# INFO:tensorflow:loss = 3.09541e+07, step = 49439 (0.508 sec)
# INFO:tensorflow:loss = 2.95967e+07, step = 49539 (0.549 sec)
# INFO:tensorflow:loss = 3.38801e+07, step = 49639 (0.515 sec)
# INFO:tensorflow:loss = 2.79742e+07, step = 49739 (0.527 sec)
# INFO:tensorflow:loss = 2.91887e+07, step = 49839 (0.507 sec)
# INFO:tensorflow:loss = 3.49944e+07, step = 49939 (0.538 sec)
# INFO:tensorflow:loss = 3.55146e+07, step = 50039 (0.507 sec)
# INFO:tensorflow:loss = 3.36605e+07, step = 50139 (0.509 sec)
# INFO:tensorflow:loss = 3.10207e+07, step = 50239 (0.503 sec)
# INFO:tensorflow:loss = 1.24359e+08, step = 50339 (0.511 sec)
# INFO:tensorflow:loss = 3.25366e+07, step = 50439 (0.508 sec)
# INFO:tensorflow:loss = 3.44204e+07, step = 50539 (0.504 sec)
# INFO:tensorflow:loss = 3.25143e+07, step = 50639 (0.524 sec)
# INFO:tensorflow:loss = 2.8406e+07, step = 50739 (0.502 sec)
# INFO:tensorflow:loss = 2.94568e+07, step = 50839 (0.531 sec)
# INFO:tensorflow:loss = 3.32626e+07, step = 50939 (0.515 sec)
# INFO:tensorflow:loss = 3.06875e+07, step = 51039 (0.531 sec)
# INFO:tensorflow:loss = 3.47308e+07, step = 51139 (0.509 sec)
# INFO:tensorflow:loss = 3.26961e+07, step = 51239 (0.509 sec)
# INFO:tensorflow:loss = 3.0719e+07, step = 51339 (0.506 sec)
# INFO:tensorflow:loss = 2.80947e+07, step = 51439 (0.525 sec)
# INFO:tensorflow:loss = 3.01554e+07, step = 51539 (0.516 sec)
# INFO:tensorflow:loss = 2.88194e+07, step = 51639 (0.514 sec)
# INFO:tensorflow:loss = 2.88858e+07, step = 51739 (0.510 sec)
# INFO:tensorflow:loss = 2.86161e+07, step = 51839 (0.507 sec)
# INFO:tensorflow:loss = 2.93372e+07, step = 51939 (0.591 sec)
# INFO:tensorflow:loss = 3.21931e+07, step = 52039 (0.702 sec)
# INFO:tensorflow:loss = 2.90446e+07, step = 52139 (0.519 sec)
# INFO:tensorflow:loss = 3.23962e+07, step = 52239 (0.509 sec)
# INFO:tensorflow:loss = 2.73071e+07, step = 52339 (0.516 sec)
# INFO:tensorflow:loss = 3.16498e+07, step = 52439 (0.524 sec)
# INFO:tensorflow:loss = 2.7274e+07, step = 52539 (0.709 sec)
# INFO:tensorflow:global_step/sec: 186.92
# INFO:tensorflow:loss = 3.12573e+07, step = 52639 (0.693 sec)
# INFO:tensorflow:loss = 2.69295e+07, step = 52739 (0.593 sec)
# INFO:tensorflow:loss = 2.80326e+07, step = 52839 (0.518 sec)
# INFO:tensorflow:loss = 3.13261e+07, step = 52939 (0.570 sec)
# INFO:tensorflow:loss = 2.58244e+07, step = 53039 (0.522 sec)
# INFO:tensorflow:loss = 3.43562e+07, step = 53139 (0.512 sec)
# INFO:tensorflow:loss = 3.14415e+07, step = 53239 (0.524 sec)
# INFO:tensorflow:loss = 3.40405e+07, step = 53339 (0.504 sec)
# INFO:tensorflow:loss = 3.58035e+07, step = 53439 (0.515 sec)
# INFO:tensorflow:loss = 2.61747e+07, step = 53539 (0.511 sec)
# INFO:tensorflow:loss = 3.48422e+07, step = 53639 (0.535 sec)
# INFO:tensorflow:loss = 3.42669e+07, step = 53739 (0.580 sec)
# INFO:tensorflow:loss = 2.62481e+07, step = 53839 (0.513 sec)
# INFO:tensorflow:loss = 2.99874e+07, step = 53939 (0.600 sec)
# INFO:tensorflow:loss = 3.28531e+07, step = 54039 (0.547 sec)
# INFO:tensorflow:loss = 3.31628e+07, step = 54139 (0.650 sec)
# INFO:tensorflow:loss = 3.15161e+07, step = 54239 (0.796 sec)
# INFO:tensorflow:loss = 3.24674e+07, step = 54339 (0.671 sec)
# INFO:tensorflow:loss = 3.17335e+07, step = 54439 (0.716 sec)
# INFO:tensorflow:loss = 2.71577e+07, step = 54539 (0.691 sec)
# INFO:tensorflow:loss = 3.08487e+07, step = 54639 (0.581 sec)
# INFO:tensorflow:loss = 3.03217e+07, step = 54739 (0.473 sec)
# INFO:tensorflow:loss = 2.98865e+07, step = 54839 (0.471 sec)
# INFO:tensorflow:loss = 3.40169e+07, step = 54939 (0.655 sec)
# INFO:tensorflow:loss = 3.06469e+07, step = 55039 (0.549 sec)
# INFO:tensorflow:loss = 3.06959e+07, step = 55139 (0.523 sec)
# INFO:tensorflow:loss = 3.42842e+07, step = 55239 (0.510 sec)
# INFO:tensorflow:loss = 2.76027e+07, step = 55339 (0.469 sec)
# INFO:tensorflow:loss = 2.79136e+07, step = 55439 (0.461 sec)
# INFO:tensorflow:loss = 3.26227e+07, step = 55539 (0.462 sec)
# INFO:tensorflow:loss = 3.01522e+07, step = 55639 (0.512 sec)
# INFO:tensorflow:loss = 2.94216e+07, step = 55739 (0.824 sec)
# INFO:tensorflow:loss = 2.9478e+07, step = 55839 (0.521 sec)
# INFO:tensorflow:loss = 3.58445e+07, step = 55939 (0.599 sec)
# INFO:tensorflow:loss = 3.51809e+07, step = 56039 (0.711 sec)
# INFO:tensorflow:loss = 3.73608e+07, step = 56139 (0.710 sec)
# INFO:tensorflow:loss = 3.44883e+07, step = 56239 (0.715 sec)
# INFO:tensorflow:loss = 3.1651e+07, step = 56339 (0.701 sec)
# INFO:tensorflow:loss = 3.27385e+07, step = 56439 (0.808 sec)
# INFO:tensorflow:loss = 3.06861e+07, step = 56539 (0.765 sec)
# INFO:tensorflow:loss = 2.92041e+07, step = 56639 (0.673 sec)
# INFO:tensorflow:Saving checkpoints for 56674 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.12534e+07.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-17:30:44
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-56674
# INFO:tensorflow:Finished evaluation at 2017-12-18-17:30:46
# INFO:tensorflow:Saving dict for global step 56674: accuracy = 0.855359, accuracy_baseline = 0.761441, auc = 0.911093, auc_precision_recall = 0.77747, average_loss = 0.310577, global_step = 56674, label/mean = 0.238559, loss = 2.90784e+07, prediction/mean = 0.242159
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Thread Count: 4
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-56674
# INFO:tensorflow:Saving checkpoints for 56675 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:loss = 3.16871e+07, step = 56675
# INFO:tensorflow:loss = 3.08548e+07, step = 56775 (0.862 sec)
# INFO:tensorflow:loss = 3.35044e+07, step = 56875 (0.490 sec)
# INFO:tensorflow:loss = 2.87333e+07, step = 56975 (0.814 sec)
# INFO:tensorflow:loss = 2.99117e+07, step = 57075 (0.482 sec)
# INFO:tensorflow:loss = 2.68876e+07, step = 57175 (0.669 sec)
# INFO:tensorflow:loss = 3.52389e+07, step = 57275 (0.541 sec)
# INFO:tensorflow:loss = 2.91709e+07, step = 57375 (0.478 sec)
# INFO:tensorflow:loss = 2.94974e+07, step = 57475 (0.463 sec)
# INFO:tensorflow:loss = 2.8024e+07, step = 57575 (0.465 sec)
# INFO:tensorflow:loss = 2.93387e+07, step = 57675 (0.507 sec)
# INFO:tensorflow:loss = 3.0416e+07, step = 57775 (0.462 sec)
# INFO:tensorflow:loss = 2.9108e+07, step = 57875 (0.462 sec)
# INFO:tensorflow:loss = 3.05703e+07, step = 57975 (0.471 sec)
# INFO:tensorflow:loss = 2.88959e+07, step = 58075 (0.457 sec)
# INFO:tensorflow:loss = 2.63591e+07, step = 58175 (0.459 sec)
# INFO:tensorflow:loss = 2.79816e+07, step = 58275 (0.463 sec)
# INFO:tensorflow:loss = 3.19031e+07, step = 58375 (0.470 sec)
# INFO:tensorflow:loss = 3.08787e+07, step = 58475 (0.465 sec)
# INFO:tensorflow:loss = 2.87387e+07, step = 58575 (0.457 sec)
# INFO:tensorflow:loss = 3.61691e+07, step = 58675 (0.459 sec)
# INFO:tensorflow:loss = 2.69465e+07, step = 58775 (0.460 sec)
# INFO:tensorflow:loss = 2.93794e+07, step = 58875 (0.458 sec)
# INFO:tensorflow:loss = 3.80918e+07, step = 58975 (0.458 sec)
# INFO:tensorflow:loss = 3.47627e+07, step = 59075 (0.461 sec)
# INFO:tensorflow:loss = 2.87151e+07, step = 59175 (0.459 sec)
# INFO:tensorflow:loss = 2.96449e+07, step = 59275 (0.459 sec)
# INFO:tensorflow:loss = 2.73889e+07, step = 59375 (0.465 sec)
# INFO:tensorflow:loss = 3.43008e+07, step = 59475 (0.469 sec)
# INFO:tensorflow:loss = 3.38725e+07, step = 59575 (0.460 sec)
# INFO:tensorflow:loss = 4.34533e+07, step = 59675 (0.464 sec)
# INFO:tensorflow:loss = 2.74037e+07, step = 59775 (0.463 sec)
# INFO:tensorflow:loss = 2.97516e+07, step = 59875 (0.466 sec)
# INFO:tensorflow:loss = 3.32554e+07, step = 59975 (0.460 sec)
# INFO:tensorflow:loss = 4.15793e+07, step = 60075 (0.463 sec)
# INFO:tensorflow:loss = 3.12165e+07, step = 60175 (0.470 sec)
# INFO:tensorflow:loss = 2.90878e+07, step = 60275 (0.504 sec)
# INFO:tensorflow:loss = 2.98612e+07, step = 60375 (0.460 sec)
# INFO:tensorflow:loss = 2.85683e+07, step = 60475 (0.460 sec)
# INFO:tensorflow:loss = 2.99659e+07, step = 60575 (0.459 sec)
# INFO:tensorflow:loss = 2.89751e+07, step = 60675 (0.464 sec)
# INFO:tensorflow:loss = 2.62038e+07, step = 60775 (0.463 sec)
# INFO:tensorflow:loss = 2.91208e+07, step = 60875 (0.463 sec)
# INFO:tensorflow:loss = 2.93811e+07, step = 60975 (0.461 sec)
# INFO:tensorflow:loss = 3.20765e+07, step = 61075 (0.460 sec)
# INFO:tensorflow:loss = 3.23797e+07, step = 61175 (0.457 sec)
# INFO:tensorflow:loss = 3.20042e+07, step = 61275 (0.459 sec)
# INFO:tensorflow:loss = 2.68266e+07, step = 61375 (0.690 sec)
# INFO:tensorflow:loss = 3.14642e+07, step = 61475 (0.464 sec)
# INFO:tensorflow:loss = 2.88927e+07, step = 61575 (0.460 sec)
# INFO:tensorflow:global_step/sec: 203.861
# INFO:tensorflow:loss = 2.70114e+07, step = 61675 (0.469 sec)
# INFO:tensorflow:loss = 2.60757e+07, step = 61775 (0.454 sec)
# INFO:tensorflow:loss = 2.73961e+07, step = 61875 (0.458 sec)
# INFO:tensorflow:loss = 3.46617e+07, step = 61975 (0.460 sec)
# INFO:tensorflow:loss = 2.65645e+07, step = 62075 (0.458 sec)
# INFO:tensorflow:loss = 3.30129e+07, step = 62175 (0.456 sec)
# INFO:tensorflow:loss = 3.01379e+07, step = 62275 (0.457 sec)
# INFO:tensorflow:loss = 4.10962e+07, step = 62375 (0.458 sec)
# INFO:tensorflow:loss = 3.46237e+07, step = 62475 (0.478 sec)
# INFO:tensorflow:loss = 2.56987e+07, step = 62575 (0.458 sec)
# INFO:tensorflow:loss = 3.12964e+07, step = 62675 (0.464 sec)
# INFO:tensorflow:loss = 3.69919e+07, step = 62775 (0.474 sec)
# INFO:tensorflow:loss = 2.5681e+07, step = 62875 (0.456 sec)
# INFO:tensorflow:loss = 3.14369e+07, step = 62975 (0.464 sec)
# INFO:tensorflow:loss = 3.29783e+07, step = 63075 (0.447 sec)
# INFO:tensorflow:loss = 3.06381e+07, step = 63175 (0.481 sec)
# INFO:tensorflow:loss = 3.04726e+07, step = 63275 (0.479 sec)
# INFO:tensorflow:loss = 3.23843e+07, step = 63375 (0.501 sec)
# INFO:tensorflow:loss = 4.52356e+07, step = 63475 (0.472 sec)
# INFO:tensorflow:loss = 2.73034e+07, step = 63575 (0.570 sec)
# INFO:tensorflow:loss = 2.82913e+07, step = 63675 (0.581 sec)
# INFO:tensorflow:loss = 3.26042e+07, step = 63775 (0.653 sec)
# INFO:tensorflow:loss = 3.20917e+07, step = 63875 (0.597 sec)
# INFO:tensorflow:loss = 3.1291e+07, step = 63975 (0.479 sec)
# INFO:tensorflow:loss = 3.20473e+07, step = 64075 (0.502 sec)
# INFO:tensorflow:loss = 2.87121e+07, step = 64175 (0.477 sec)
# INFO:tensorflow:loss = 3.72909e+07, step = 64275 (0.484 sec)
# INFO:tensorflow:loss = 2.74875e+07, step = 64375 (0.504 sec)
# INFO:tensorflow:loss = 2.78671e+07, step = 64475 (0.472 sec)
# INFO:tensorflow:loss = 3.29256e+07, step = 64575 (0.522 sec)
# INFO:tensorflow:loss = 2.82169e+07, step = 64675 (0.547 sec)
# INFO:tensorflow:loss = 3.00124e+07, step = 64775 (0.534 sec)
# INFO:tensorflow:loss = 2.8731e+07, step = 64875 (0.634 sec)
# INFO:tensorflow:loss = 2.84877e+07, step = 64975 (0.669 sec)
# INFO:tensorflow:loss = 3.76634e+07, step = 65075 (0.548 sec)
# INFO:tensorflow:Saving checkpoints for 65122 into trained_models/cenus-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.73265e+06.
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-17:31:47
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-65122
# INFO:tensorflow:Finished evaluation at 2017-12-18-17:31:50
# INFO:tensorflow:Saving dict for global step 65122: accuracy = 0.856529, accuracy_baseline = 0.761441, auc = 0.911788, auc_precision_recall = 0.7783, average_loss = 0.314239, global_step = 65122, label/mean = 0.238559, loss = 2.94212e+07, prediction/mean = 0.264458
# .......................................
# Experiment finished at 17:31:50
#
# Experiment elapsed time: 493.618966 seconds

# %% [markdown]
# ## Evaluate the Model

# %%
TRAIN_SIZE = TRAIN_DATA_SIZE
TEST_SIZE = TEST_DATA_SIZE

train_input_fn = lambda: csv_input_fn(files_name_pattern= TRAIN_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TRAIN_SIZE)

test_input_fn = lambda: csv_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TEST_SIZE)

estimator = create_DNNComb_estimator(run_config, hparams)

train_results = estimator.evaluate(input_fn=train_input_fn, steps=1)
print()
print("######################################################################################")
print("# Train Measures: {}".format(train_results))
print("######################################################################################")

test_results = estimator.evaluate(input_fn=test_input_fn, steps=1)
print()
print("######################################################################################")
print("# Test Measures: {}".format(test_results))
print("######################################################################################")
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'trained_models/cenus-model-01', '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 5000, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1204cd6d8>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# * data input_fn:
# ================
# Input file(s): data/adult.data.csv
# Batch size: 32561
# Epoch Count: None
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-17:31:53
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-65122
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-12-18-17:31:56
# INFO:tensorflow:Saving dict for global step 65122: accuracy = 0.856529, accuracy_baseline = 0.761441, auc = 0.911788, auc_precision_recall = 0.7783, average_loss = 0.314239, global_step = 65122, label/mean = 0.238559, loss = 1.9418e+09, prediction/mean = 0.264458
#
# ######################################################################################
# # Train Measures: {'accuracy': 0.85652918, 'accuracy_baseline': 0.76144063, 'auc': 0.91178799, 'auc_precision_recall': 0.77829981, 'average_loss': 0.31423873, 'label/mean': 0.23855937, 'loss': 1.9417987e+09, 'prediction/mean': 0.26445815, 'global_step': 65122}
# ######################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/adult.test.csv
# Batch size: 16278
# Epoch Count: None
# Mode: eval
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-18-17:32:00
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-65122
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-12-18-17:32:02
# INFO:tensorflow:Saving dict for global step 65122: accuracy = 0.853939, accuracy_baseline = 0.763804, auc = 0.910893, auc_precision_recall = 0.772826, average_loss = 0.314562, global_step = 65122, label/mean = 0.236196, loss = 9.6997e+08, prediction/mean = 0.263387
#
# ######################################################################################
# # Test Measures: {'accuracy': 0.85393894, 'accuracy_baseline': 0.76380354, 'auc': 0.9108929, 'auc_precision_recall': 0.77282554, 'average_loss': 0.31456164, 'label/mean': 0.23619646, 'loss': 9.6996954e+08, 'prediction/mean': 0.26338705, 'global_step': 65122}
# ######################################################################################

# %% [markdown]
# ## Prediction

# %%
import itertools

predict_input_fn = lambda: csv_input_fn(TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.PREDICT,
                                      batch_size= 10)


predictions = list(itertools.islice(estimator.predict(input_fn=predict_input_fn),10))

print("")
print("* Predicted Classes: {}".format(list(map(lambda item: item["class_ids"][0]
    ,predictions))))

print("* Predicted Probabilities: {}".format(list(map(lambda item: list(item["probabilities"])
    ,predictions))))
# Out:
# * data input_fn:
# ================
# Input file(s): data/adult.test.csv
# Batch size: 10
# Epoch Count: None
# Mode: infer
# Thread Count: 4
# Shuffle: False
# ================
#
# WARNING:tensorflow:Input graph does not contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Restoring parameters from trained_models/cenus-model-01/model.ckpt-65122
#
# * Predicted Classes: [0, 0, 0, 1, 0, 0, 0, 1, 0, 0]
# * Predicted Probabilities: [[0.99085402, 0.0091459062], [0.82574034, 0.17425966], [0.55082226, 0.44917768], [0.064317025, 0.93568295], [0.98892516, 0.01107486], [0.98782885, 0.01217118], [0.98744464, 0.012555314], [0.12526204, 0.87473798], [0.98674554, 0.01325444], [0.93313622, 0.066863775]]
